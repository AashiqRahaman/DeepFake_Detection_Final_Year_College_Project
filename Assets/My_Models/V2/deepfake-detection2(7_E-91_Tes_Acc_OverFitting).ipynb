# %% [markdown]
# ### Cell 1: Check Data Directories
# This step remains the same.

# %%
# !ls /kaggle/input/1000-videos-split/1000_videos/train/fake | head -n 5
# !ls /kaggle/input/1000-videos-split/1000_videos/train/real | head -n 5
# Out:
# 128_896_10.png
# 128_896_11.png
# 128_896_12.png
# 128_896_13.png
# 128_896_14.png
# ls: write error: Broken pipe
# 129_10.png
# 129_2.png
# 129_3.png
# 129_4.png
# 129_5.png
# ls: write error: Broken pipe

# %% [markdown]
# ### Hardware Detection
#
# This cell runs a check to identify the available hardware and selects the appropriate TensorFlow distribution strategy.

# %%
import tensorflow as tf
import os

def get_distribution_strategy():
    """
    Detects available hardware (TPU, multi-GPU, single-GPU, CPU) and returns
    the appropriate TensorFlow distribution strategy.
    """
    try:
        # Attempt to detect and initialize a TPU
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        strategy = tf.distribute.TPUStrategy(tpu)
        print("✅ Running on TPU")
    except (ValueError, tf.errors.NotFoundError):
        # If no TPU is found, check for GPUs
        gpus = tf.config.list_physical_devices('GPU')
        if len(gpus) > 1:
            # If multiple GPUs are available, use MirroredStrategy
            strategy = tf.distribute.MirroredStrategy()
            print(f"✅ Running on {len(gpus)} GPUs")
        elif len(gpus) == 1:
            # If a single GPU is available, use the default strategy
            strategy = tf.distribute.get_strategy()
            print("✅ Running on a single GPU")
        else:
            # If no GPUs are found, run on CPU
            strategy = tf.distribute.get_strategy()
            print("✅ Running on CPU")
            
    print(f"Number of accelerator replicas: {strategy.num_replicas_in_sync}")
    return strategy

# Run the detection function to see what hardware is available
strategy = get_distribution_strategy()
# Out:
# 2025-09-30 07:22:25.515779: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759216945.709022      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759216945.767413      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ✅ Running on a single GPU
# Number of accelerator replicas: 1

# %% [markdown]
# ### Cell 3: Introduction
# This cell provides an overview of the notebook's purpose and structure.
#
# # Deepfake Detection with Soft Attention
#
# This notebook sets up and runs the Deepfake Video Forgery Detection project using the original provided Python scripts. The process is broken down into clear, documented stages:
#
# 1.  **Setup and Writing Project Files:** Each of the original Python scripts (`model.py`, `utils.py`, `train.py`, `main.py`) will be written to the Kaggle environment. Critical, minimal fixes are applied to ensure the project can run and save the final model.
# 2.  **Training the Model:** The main training script is executed using a command line call, just as designed in the original project.
# 3.  **Prediction:** A final script is provided to easily test the trained model on new images.

# %% [markdown]
# ### Writing `model.py`
#
# This script defines the neural network architecture. The following critical modifications were necessary:
#
# -   **Corrected Layer Instantiation:** Layers are now correctly defined once in the `build()` method and used in the `call()` method. This is essential to allow the model to be saved.
# -   **Added `**kwargs`:** The `__init__` methods of the custom layers have been updated to accept extra arguments from Keras during model loading.

# %%
# %%writefile model.py
import tensorflow as tf

def backbone():
    '''
    RETURNS THE BACKBONE FEATURE ENCODER NETWORK
    XCEPTION USED IN THIS CASE
    '''
    mod  = tf.keras.applications.Xception(weights='imagenet')
    mod = tf.keras.Model(mod.input, mod.layers[-13].output)
    return mod
    
class ModifiedBranch(tf.keras.layers.Layer):
    '''
    COMPUTES THE MODIFIED BRANCH TO BE USED IN ATTENTION TECHNIQUE
    '''
    def __init__(self, a_vec_size, **kwargs):
        super(ModifiedBranch, self).__init__(**kwargs)
        self.a_vec_size = a_vec_size

    def build(self, input_shape):
        self.dense_layer = tf.keras.layers.Dense(self.a_vec_size, activation='tanh')

    def call(self, input):
        af = tf.keras.backend.mean(input, axis=2) 
        hs = self.dense_layer(af)
        return hs

class MainBranch(tf.keras.layers.Layer):
    def __init__(self, a_vec_size, dim, **kwargs):
        super(MainBranch, self).__init__(**kwargs)
        self.a_vec_size = a_vec_size
        self.dim = dim

    def build(self, input_shape):
        self.reshape1 = tf.keras.layers.Reshape((-1, self.a_vec_size))
        self.relu = tf.keras.activations.relu
        self.dropout = tf.keras.layers.Dropout(0.5)
        self.reshape2 = tf.keras.layers.Reshape((self.dim**2, self.a_vec_size))

    def call(self, input):
        e = tf.transpose(input, perm=[0, 2, 1])
        e = self.reshape1(e)
        e = self.relu(e)
        e = self.dropout(e)
        e = self.reshape2(e)
        e = tf.transpose(e, perm=[0, 2, 1])
        return e

class Attention(tf.keras.layers.Layer):
    '''
    IMPLEMENTATION OF THE ATTENTION TECHNIQUE ON TWO BRANCHES
    '''
    def __init__(self, dim, a_vec_size, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dim = dim
        self.a_vec_size = a_vec_size
    
    def build(self, input_shape):
        self.dense1 = tf.keras.layers.Dense(self.dim**2)
        self.reshape1 = tf.keras.layers.Reshape((1, self.dim**2))
        self.add = tf.keras.layers.Add()
        self.dropout = tf.keras.layers.Dropout(0.5)
        self.relu = tf.keras.activations.relu
        self.reshape2 = tf.keras.layers.Reshape((-1, self.a_vec_size))
        self.dense2 = tf.keras.layers.Dense(1, use_bias=False)
        self.reshape3 = tf.keras.layers.Reshape((-1, self.dim**2))

    def call(self, input):
        eh = self.dense1(input[0])
        eh = self.reshape1(eh)
        eh = self.add([input[1], eh])
        eh = self.relu(eh)
        eh = self.dropout(eh)
        eh = tf.transpose(eh, perm=[0, 2, 1])
        eh = self.reshape2(eh)
        eh = self.dense2(eh)
        eh = self.reshape3(eh)
        eh = self.relu(eh)
        return eh

def model(a_vec_size, dim):
    '''
    THIS FUNCTION CALLS THE ENTIRE MODEL
    '''
    back = backbone()
    backbone_feature = back.output  
    out = tf.keras.layers.Conv2D(filters = a_vec_size, kernel_size = (1,1), strides=(1,1), padding = 'valid', use_bias=True)(backbone_feature)
    out = tf.keras.layers.BatchNormalization(axis=-1)(out)
    out = tf.keras.activations.relu(out)
    out = tf.keras.layers.Dropout(0.8)(out)
    out = tf.keras.layers.Reshape((a_vec_size, dim**2))(out)
    
    modified = ModifiedBranch(a_vec_size)(out)
    main = MainBranch(a_vec_size, dim)(out)
    att = Attention(dim, a_vec_size)([modified, main])
    fin = tf.keras.layers.Dense(2, activation='softmax')(att)
    fin = tf.keras.layers.Flatten()(fin)
    mod = tf.keras.Model(inputs=back.input, outputs=fin)
    return mod
# Out:
# Writing model.py

# %% [markdown]
# ### Writing `utils.py`
#
# This script handles data loading. The following modifications were essential:
#
# -   **Corrected Label Reading:** The `get_output` function was changed to read the label from the parent directory name (e.g., `.../fake/` or `.../real/`).
# -   **Added Preprocessing:** The `image_generator` now correctly applies `preprocess_input` for the Xception model, which is critical for transfer learning.

# %%
# %%writefile utils.py
import os
import cv2
import glob
import numpy as np
from tensorflow.keras.applications.xception import preprocess_input

def get_input(path):
    im = cv2.imread(path)
    return(im)

def get_files(path, ext):
    files = []
    label_files= []
    for x in os.walk(path):
        for y in glob.glob(os.path.join(x[0], '*.{}'.format(ext))):
            files.append(y)
    label_files = ['fake', 'real']
    return files, label_files

def get_output(path, label_file):
    img_id = path.split('/')[-2] 
    laba = []
    for label in label_file:
      if label == img_id:
        laba.append(1)
      else:
        laba.append(0)
    return laba

def image_generator(files, label_files, batch_size, resize=None):
    while True:
          batch_paths  = np.random.choice(a  = files, 
                                          size = batch_size)
          batch_x = []
          batch_y = [] 
          
          for input_path in batch_paths:
              input_img = get_input(input_path)
              output = get_output(input_path, label_files)
              
              if resize is not None:
                input_img = cv2.resize(input_img, resize)
              
              input_img = preprocess_input(input_img) 
              
              batch_x.append(input_img)
              batch_y.append(output)

          batch_x = np.array(batch_x)
          batch_y = np.array(batch_y)
          yield batch_x, batch_y
# Out:
# Writing utils.py

# %% [markdown]
# ### Writing `train.py` (Modified for Universal Compatibility)
#
# This script is the main training engine. It has been significantly modified to support all hardware types:
#
# -   **Universal Hardware Detection:** It includes a function that detects TPUs, multiple GPUs, a single GPU, or defaults to CPU.
# -   **Strategy Scope:** The model creation and compilation steps are now correctly placed inside the appropriate `strategy.scope()`, which is a requirement for all forms of distributed training (TPU and multi-GPU).
# -   **Enabled Model Checkpointing:** The `ModelCheckpoint` callback is enabled to save the best version of the model.

# %%
# %%writefile train.py
import os
import utils
import model
import tensorflow as tf

def get_distribution_strategy():
    """
    Detects available hardware (TPU, multi-GPU, single-GPU, CPU) and returns
    the appropriate TensorFlow distribution strategy.
    """
    try:
        # Attempt to detect and initialize a TPU
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        strategy = tf.distribute.TPUStrategy(tpu)
        print("✅ Running on TPU")
    except (ValueError, tf.errors.NotFoundError):
        # If no TPU is found, check for GPUs
        gpus = tf.config.list_physical_devices('GPU')
        if len(gpus) > 1:
            # If multiple GPUs are available, use MirroredStrategy
            strategy = tf.distribute.MirroredStrategy()
            print(f"✅ Running on {len(gpus)} GPUs")
        elif len(gpus) == 1:
            # If a single GPU is available, use the default strategy
            strategy = tf.distribute.get_strategy()
            print("✅ Running on a single GPU")
        else:
            # If no GPUs are found, run on CPU
            strategy = tf.distribute.get_strategy()
            print("✅ Running on CPU")
            
    print(f"Number of accelerator replicas: {strategy.num_replicas_in_sync}")
    return strategy

class train():
    def __init__(self, train_path, val_path):
        self.train_path = train_path
        self.val_path = val_path
        here = os.path.dirname(os.path.abspath(__file__))
        self.path = os.path.join(here, "models")
        os.makedirs(self.path, exist_ok=True)
    
    def get_files(self):
        self.train_files, self.label_files = utils.get_files(self.train_path, 'png')
        self.val_files, self.label_files = utils.get_files(self.val_path, 'png')

    def run(self, epochs, batch_size, steps, dim=(299, 299)):
        self.get_files()
        
        # MODIFICATION: Get the appropriate strategy for the available hardware
        strategy = get_distribution_strategy()

        # MODIFICATION: The model must be created and compiled inside the strategy's scope.
        with strategy.scope():
            mod = model.model(1024, 19)
            mod.compile('Adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])

        print("************TRAINING SOFT ATTENTION BASED DEEP FAKE DETECTION MODEL************")
        
        checkpoint_filepath = os.path.join(self.path, "best_model.keras")
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath, 
            save_best_only=True, 
            monitor='val_accuracy', 
            mode='max'
        )

        mod.fit(utils.image_generator(self.train_files, self.label_files, batch_size, dim), 
                  epochs=epochs, 
                  steps_per_epoch=steps,
                  validation_data=utils.image_generator(self.val_files, self.label_files, batch_size, dim),
                  validation_steps=150,
                  callbacks=[model_checkpoint_callback])
# Out:
# Writing train.py

# %% [markdown]
# ### Writing `main.py`
#
# This script parses command-line arguments and starts the training. No modifications were needed.

# %%
# %%writefile main.py
import argparse
from train import train

def main():
    parser = argparse.ArgumentParser(description='Visual Attention based Deepfake Video Forgery Detection')

    parser.add_argument('--train', type=str, nargs = '+', help = 'What is the path of the training image data?')
    parser.add_argument('--val', type=str, nargs = '+', help = 'What is the path of the Validation image data?')
    parser.add_argument('--epochs', type=int, default=50, help = 'What is the training epoch for model?')
    parser.add_argument('--batch', type=int, default=32, help = 'What is the training batch size?')
    parser.add_argument('--steps', type=int, default=40, help = 'What is the training steps per epoch?')

    args = parser.parse_args()
    args.train = ' '.join(args.train)
    args.val = ' '.join(args.val)

    print("Configuration")
    print("----------------------------------------------------------------------")
    print("Training Path : {}".format(args.train))
    print("Validation Path : {}".format(args.val))
    print("Epochs while training the model : {}".format(args.epochs))
    print("Batch Size : {}".format(args.batch))
    print("Steps per epochs : {}".format(args.steps))
    print("----------------------------------------------------------------------")

    train(args.train, args.val).run(args.epochs, args.batch, args.steps)

if __name__=='__main__':
    main()
# Out:
# Writing main.py

# %% [markdown]
# ## Stage 2: Training the Model
#
# Now that all scripts are written and corrected, we can run the training process.
#
# **Important:** You must update the `--train` and `--val` paths below to point to your dataset's location in the Kaggle input directory (e.g., `/kaggle/input/your-dataset-name/...`). You should also calculate and set the `--steps` argument properly.
#
# **How to calculate `--steps`:**
# `steps = (total_number_of_training_images) / batch_size`

# %%
# Example Usage: total file no /batch = steps

# !python main.py \
    --train "/kaggle/input/1000-videos-split/1000_videos/train" \
    --val "/kaggle/input/1000-videos-split/1000_videos/validation" \
    --epochs 30 \
    --batch 16 \
    --steps 727
# Out:
# 2025-09-30 07:22:38.667687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759216958.688155      93 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759216958.694237      93 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Configuration
# ----------------------------------------------------------------------
# Training Path : /kaggle/input/1000-videos-split/1000_videos/train
# Validation Path : /kaggle/input/1000-videos-split/1000_videos/validation
# Epochs while training the model : 30
# Batch Size : 16
# Steps per epochs : 727
# ----------------------------------------------------------------------
# ✅ Running on a single GPU
# Number of accelerator replicas: 1
# I0000 00:00:1759216974.861459      93 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# ************TRAINING SOFT ATTENTION BASED DEEP FAKE DETECTION MODEL************
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759217010.381220     114 service.cc:148] XLA service 0x7c61340037a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759217010.382210     114 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759217013.328364     114 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1759217023.901951     114 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759217024.111579     114 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759217025.188674     114 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759217025.420124     114 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759217026.340217     114 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759217026.528868     114 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1759217035.552454     114 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 237s 251ms/step - accuracy: 0.6782 - loss: 0.7358 - val_accuracy: 0.8696 - val_loss: 0.4658
# Epoch 2/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 244ms/step - accuracy: 0.9299 - loss: 0.1789 - val_accuracy: 0.9175 - val_loss: 0.4373
# Epoch 3/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9577 - loss: 0.1299 - val_accuracy: 0.6554 - val_loss: 0.6098
# Epoch 4/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9635 - loss: 0.1130 - val_accuracy: 0.9058 - val_loss: 0.3621
# Epoch 5/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9513 - loss: 0.1382 - val_accuracy: 0.8963 - val_loss: 0.5025
# Epoch 6/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9649 - loss: 0.0988 - val_accuracy: 0.7317 - val_loss: 0.6243
# Epoch 7/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 178s 244ms/step - accuracy: 0.9359 - loss: 0.1623 - val_accuracy: 0.9233 - val_loss: 0.3822
# Epoch 8/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.9754 - loss: 0.0632 - val_accuracy: 0.8942 - val_loss: 0.3436
# Epoch 9/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 180s 248ms/step - accuracy: 0.9565 - loss: 0.1167 - val_accuracy: 0.6625 - val_loss: 0.5103
# Epoch 10/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9661 - loss: 0.0996 - val_accuracy: 0.5942 - val_loss: 0.6572
# Epoch 11/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9309 - loss: 0.1684 - val_accuracy: 0.8537 - val_loss: 0.4877
# Epoch 12/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9518 - loss: 0.1399 - val_accuracy: 0.8192 - val_loss: 0.5021
# Epoch 13/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.9781 - loss: 0.0627 - val_accuracy: 0.8008 - val_loss: 0.4467
# Epoch 14/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 242ms/step - accuracy: 0.9787 - loss: 0.0569 - val_accuracy: 0.8537 - val_loss: 0.4089
# Epoch 15/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 176s 243ms/step - accuracy: 0.9359 - loss: 0.1766 - val_accuracy: 0.7550 - val_loss: 0.5215
# Epoch 16/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.9117 - loss: 0.2308 - val_accuracy: 0.8225 - val_loss: 0.5205
# Epoch 17/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 178s 244ms/step - accuracy: 0.9444 - loss: 0.1476 - val_accuracy: 0.8646 - val_loss: 0.5019
# Epoch 18/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.9213 - loss: 0.1970 - val_accuracy: 0.6350 - val_loss: 0.6622
# Epoch 19/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 244ms/step - accuracy: 0.8740 - loss: 0.2951 - val_accuracy: 0.5167 - val_loss: 0.6911
# Epoch 20/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.7185 - loss: 0.5166 - val_accuracy: 0.5046 - val_loss: 0.6119
# Epoch 21/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.9158 - loss: 0.2068 - val_accuracy: 0.5387 - val_loss: 0.6243
# Epoch 22/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 178s 245ms/step - accuracy: 0.9428 - loss: 0.1448 - val_accuracy: 0.8679 - val_loss: 0.5101
# Epoch 23/30
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 177s 243ms/step - accuracy: 0.8987 - loss: 0.2527 - val_accuracy: 0.6221 - val_loss: 0.6813
# Epoch 24/30
#  74/727 ━━━━━━━━━━━━━━━━━━━━ 2:30 230ms/step - accuracy: 0.6907 - loss: 0.6313^C
# Traceback (most recent call last):
#   File "/kaggle/working/main.py", line 29, in <module>
#     main()
#   File "/kaggle/working/main.py", line 26, in main
#     train(args.train, args.val).run(args.epochs, args.batch, args.steps)
#   File "/kaggle/working/train.py", line 68, in run
#     mod.fit(utils.image_generator(self.train_files, self.label_files, batch_size, dim),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#     logs = self.train_function(iterator)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 220, in function
#     if not opt_outputs.has_value():
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/data/ops/optional_ops.py", line 176, in has_value
#     return gen_optional_ops.optional_has_value(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_optional_ops.py", line 172, in optional_has_value
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !zip -r my_model.zip models/
# Out:
#   adding: models/ (stored 0%)
#   adding: models/best_model.keras (deflated 8%)

# %% [markdown]
# ## Stage 3: Prediction
#
# After training, a file named `best_model.keras` will be saved in the `/kaggle/working/models/` directory. We can use this model to make predictions on new, unseen images.
#
# First, we'll write a `predict.py` script to handle loading the model and processing an image.

# %%
# %%writefile predict.py
import tensorflow as tf
import numpy as np
import cv2
import argparse
import os

# --- Import your custom layers and preprocessing function ---
from model import ModifiedBranch, MainBranch, Attention
from tensorflow.keras.applications.xception import preprocess_input

# Define the labels list globally
LABELS = ['fake', 'real']

def load_and_prep_image(image_path, target_size=(299, 299)):
    """
    Loads, resizes, and preprocesses a single image.
    Returns None if the image cannot be read.
    """
    try:
        img = cv2.imread(image_path)
        if img is None:
            print(f"Warning: Could not read image {image_path}. Skipping.")
            return None
            
        img = cv2.resize(img, target_size)
        img_preprocessed = preprocess_input(img)
        return np.expand_dims(img_preprocessed, axis=0)
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return None

def predict_single_image(model, image_path):
    """
    Loads a single image, predicts it, and prints the result.
    """
    image_batch = load_and_prep_image(image_path)
    if image_batch is None: return

    print("Predicting...")
    prediction = model.predict(image_batch)
    
    predicted_index = np.argmax(prediction[0])
    predicted_label = LABELS[predicted_index]
    confidence = prediction[0][predicted_index] * 100

    print("\n--- Prediction Result ---")
    print(f"       File: {os.path.basename(image_path)}")
    print(f"Prediction is: {predicted_label.upper()}")
    print(f"  Confidence: {confidence:.2f}%")
    print("-------------------------")

def evaluate_folder(model, folder_path):
    """
    Recursively evaluates all images in a given folder.
    """
    print(f"Scanning folder: {folder_path}\nThis may take a while...")
    total_files = 0
    correct_predictions = 0
    
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if not filename.lower().endswith(('.png', '.jpg', '.jpeg')): continue
            true_label = os.path.basename(root).lower()
            if true_label not in LABELS: continue

            image_path = os.path.join(root, filename)
            image_batch = load_and_prep_image(image_path)
            if image_batch is None: continue
            
            total_files += 1
            prediction = model.predict(image_batch, verbose=0)
            predicted_index = np.argmax(prediction[0])
            predicted_label = LABELS[predicted_index]

            # --- MODIFICATION IS HERE ---
            confidence = prediction[0][predicted_index] * 100

            if predicted_label == true_label:
                correct_predictions += 1
                result = "CORRECT"
            else:
                result = "WRONG"
            
            # --- AND HERE ---
            print(f"  > File: {filename} | True: {true_label} | Predicted: {predicted_label} ({confidence:.2f}%)  [{result}]")

    if total_files > 0:
        accuracy = (correct_predictions / total_files) * 100
        print("\n--- Evaluation Summary ---")
        print(f"Total Images: {total_files}")
        print(f"Correct Predictions: {correct_predictions}")
        print(f"OVERALL ACCURACY: {accuracy:.2f}%")
        print("--------------------------")
    else:
        print("\nNo valid image files found in 'fake' or 'real' subdirectories.")

def main():
    parser = argparse.ArgumentParser(description='Predict if an image is real or fake.')
    parser.add_argument('--input_path', type=str, required=True, help='Path to an image file OR a folder.')
    parser.add_argument('--model_path', type=str, default='models/best_model.keras', help='Path to the saved model file.')
    args = parser.parse_args()

    if not os.path.exists(args.model_path):
        print(f"Error: Model file not found at {args.model_path}")
        return

    custom_objects = {"ModifiedBranch": ModifiedBranch, "MainBranch": MainBranch, "Attention": Attention}
    print("Loading model...")
    model = tf.keras.models.load_model(args.model_path, custom_objects=custom_objects)
    print("Model loaded.")

    if os.path.isfile(args.input_path):
        predict_single_image(model, args.input_path)
    elif os.path.isdir(args.input_path):
        evaluate_folder(model, args.input_path)
    else:
        print(f"Error: Input path is not a valid file or directory: {args.input_path}")

if __name__ == "__main__":
    main()
# Out:
# Writing predict.py

# %% [markdown]
# ### Running Prediction
#
# Use the command below to test your saved model. You will need to provide a valid path to an image from your dataset.

# %%
# Example of how to run prediction on a single image from your validation set.
# You will need to find a valid path to an image.

# !python predict.py --image "/kaggle/input/1000-videos-split/1000_videos/validation/fake/000_003_0.png"
# !python predict.py --input_path "/kaggle/input/1000-videos-split/1000_videos/test"
# Out:
# 2025-09-30 08:32:16.060571: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759221136.083315     369 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759221136.090132     369 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading model...
# I0000 00:00:1759221140.560632     369 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model loaded.
# Scanning folder: /kaggle/input/1000-videos-split/1000_videos/test
# This may take a while...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759221147.199756     390 service.cc:148] XLA service 0x7b6670002c80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759221147.199823     390 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759221147.564524     390 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1759221149.411638     390 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   > File: 113_983_1.png | True: fake | Predicted: fake (91.53%)  [CORRECT]
#   > File: 095_053_38.png | True: fake | Predicted: fake (73.25%)  [CORRECT]
#   > File: 089_065_4.png | True: fake | Predicted: fake (84.05%)  [CORRECT]
#   > File: 074_825_2.png | True: fake | Predicted: fake (56.20%)  [CORRECT]
#   > File: 076_079_0.png | True: fake | Predicted: fake (87.52%)  [CORRECT]
#   > File: 096_101_3.png | True: fake | Predicted: fake (83.79%)  [CORRECT]
#   > File: 099_295_20.png | True: fake | Predicted: fake (91.72%)  [CORRECT]
#   > File: 071_054_10.png | True: fake | Predicted: fake (51.96%)  [CORRECT]
#   > File: 091_116_5.png | True: fake | Predicted: fake (90.26%)  [CORRECT]
#   > File: 113_983_19.png | True: fake | Predicted: fake (92.77%)  [CORRECT]
#   > File: 078_955_12.png | True: fake | Predicted: fake (74.85%)  [CORRECT]
#   > File: 113_983_5.png | True: fake | Predicted: fake (94.47%)  [CORRECT]
#   > File: 080_061_6.png | True: fake | Predicted: real (52.35%)  [WRONG]
#   > File: 121_093_12.png | True: fake | Predicted: fake (73.28%)  [CORRECT]
#   > File: 127_129_26.png | True: fake | Predicted: fake (61.10%)  [CORRECT]
#   > File: 119_123_1.png | True: fake | Predicted: fake (90.35%)  [CORRECT]
#   > File: 127_129_1.png | True: fake | Predicted: fake (53.06%)  [CORRECT]
#   > File: 068_028_4.png | True: fake | Predicted: fake (95.37%)  [CORRECT]
#   > File: 091_116_15.png | True: fake | Predicted: fake (72.57%)  [CORRECT]
#   > File: 072_037_7.png | True: fake | Predicted: fake (91.99%)  [CORRECT]
#   > File: 116_091_5.png | True: fake | Predicted: fake (64.22%)  [CORRECT]
#   > File: 098_092_6.png | True: fake | Predicted: fake (92.23%)  [CORRECT]
#   > File: 114_102_20.png | True: fake | Predicted: real (52.27%)  [WRONG]
#   > File: 101_096_32.png | True: fake | Predicted: fake (96.27%)  [CORRECT]
#   > File: 095_053_26.png | True: fake | Predicted: fake (83.59%)  [CORRECT]
#   > File: 127_129_6.png | True: fake | Predicted: fake (71.22%)  [CORRECT]
#   > File: 081_087_11.png | True: fake | Predicted: fake (77.31%)  [CORRECT]
#   > File: 080_061_11.png | True: fake | Predicted: fake (66.15%)  [CORRECT]
#   > File: 127_129_15.png | True: fake | Predicted: fake (72.69%)  [CORRECT]
#   > File: 089_065_8.png | True: fake | Predicted: fake (92.12%)  [CORRECT]
#   > File: 096_101_12.png | True: fake | Predicted: fake (74.16%)  [CORRECT]
#   > File: 083_213_8.png | True: fake | Predicted: fake (90.72%)  [CORRECT]
#   > File: 099_295_4.png | True: fake | Predicted: fake (78.93%)  [CORRECT]
#   > File: 106_198_6.png | True: fake | Predicted: fake (71.65%)  [CORRECT]
#   > File: 081_087_16.png | True: fake | Predicted: fake (62.09%)  [CORRECT]
#   > File: 100_077_4.png | True: fake | Predicted: fake (80.65%)  [CORRECT]
#   > File: 086_090_9.png | True: fake | Predicted: fake (87.63%)  [CORRECT]
#   > File: 118_120_10.png | True: fake | Predicted: real (52.60%)  [WRONG]
#   > File: 084_042_10.png | True: fake | Predicted: fake (86.92%)  [CORRECT]
#   > File: 081_087_43.png | True: fake | Predicted: fake (56.27%)  [CORRECT]
#   > File: 117_217_17.png | True: fake | Predicted: fake (83.97%)  [CORRECT]
#   > File: 101_096_35.png | True: fake | Predicted: fake (99.32%)  [CORRECT]
#   > File: 094_111_10.png | True: fake | Predicted: fake (70.77%)  [CORRECT]
#   > File: 126_104_5.png | True: fake | Predicted: fake (85.87%)  [CORRECT]
#   > File: 114_102_12.png | True: fake | Predicted: fake (87.23%)  [CORRECT]
#   > File: 117_217_2.png | True: fake | Predicted: fake (65.88%)  [CORRECT]
#   > File: 082_103_12.png | True: fake | Predicted: fake (97.62%)  [CORRECT]
#   > File: 114_102_8.png | True: fake | Predicted: fake (74.76%)  [CORRECT]
#   > File: 078_955_8.png | True: fake | Predicted: fake (85.37%)  [CORRECT]
#   > File: 107_109_1.png | True: fake | Predicted: fake (79.87%)  [CORRECT]
#   > File: 110_043_12.png | True: fake | Predicted: fake (78.05%)  [CORRECT]
#   > File: 082_103_6.png | True: fake | Predicted: fake (88.33%)  [CORRECT]
#   > File: 102_114_3.png | True: fake | Predicted: fake (99.05%)  [CORRECT]
#   > File: 068_028_6.png | True: fake | Predicted: fake (91.70%)  [CORRECT]
#   > File: 107_109_16.png | True: fake | Predicted: fake (86.33%)  [CORRECT]
#   > File: 078_955_15.png | True: fake | Predicted: fake (87.99%)  [CORRECT]
#   > File: 112_892_7.png | True: fake | Predicted: fake (76.98%)  [CORRECT]
#   > File: 090_086_16.png | True: fake | Predicted: fake (63.06%)  [CORRECT]
#   > File: 084_042_7.png | True: fake | Predicted: fake (97.05%)  [CORRECT]
#   > File: 089_065_6.png | True: fake | Predicted: fake (69.25%)  [CORRECT]
#   > File: 101_096_23.png | True: fake | Predicted: fake (99.74%)  [CORRECT]
#   > File: 102_114_6.png | True: fake | Predicted: fake (97.37%)  [CORRECT]
#   > File: 097_033_10.png | True: fake | Predicted: real (55.29%)  [WRONG]
#   > File: 099_295_22.png | True: fake | Predicted: fake (92.79%)  [CORRECT]
#   > File: 118_120_2.png | True: fake | Predicted: real (50.46%)  [WRONG]
#   > File: 088_060_15.png | True: fake | Predicted: real (51.37%)  [WRONG]
#   > File: 082_103_2.png | True: fake | Predicted: fake (97.83%)  [CORRECT]
#   > File: 122_144_10.png | True: fake | Predicted: fake (88.31%)  [CORRECT]
#   > File: 077_100_16.png | True: fake | Predicted: fake (53.78%)  [CORRECT]
#   > File: 114_102_33.png | True: fake | Predicted: fake (50.12%)  [CORRECT]
#   > File: 102_114_14.png | True: fake | Predicted: fake (97.01%)  [CORRECT]
#   > File: 088_060_22.png | True: fake | Predicted: real (52.40%)  [WRONG]
#   > File: 106_198_4.png | True: fake | Predicted: fake (93.83%)  [CORRECT]
#   > File: 101_096_15.png | True: fake | Predicted: fake (99.57%)  [CORRECT]
#   > File: 114_102_32.png | True: fake | Predicted: real (52.44%)  [WRONG]
#   > File: 102_114_5.png | True: fake | Predicted: fake (93.90%)  [CORRECT]
#   > File: 086_090_16.png | True: fake | Predicted: fake (97.57%)  [CORRECT]
#   > File: 089_065_18.png | True: fake | Predicted: fake (76.29%)  [CORRECT]
#   > File: 111_094_6.png | True: fake | Predicted: fake (56.96%)  [CORRECT]
#   > File: 095_053_36.png | True: fake | Predicted: fake (52.07%)  [CORRECT]
#   > File: 088_060_21.png | True: fake | Predicted: real (51.78%)  [WRONG]
#   > File: 116_091_8.png | True: fake | Predicted: fake (76.96%)  [CORRECT]
#   > File: 120_118_10.png | True: fake | Predicted: fake (51.27%)  [CORRECT]
#   > File: 110_043_9.png | True: fake | Predicted: fake (62.85%)  [CORRECT]
#   > File: 095_053_12.png | True: fake | Predicted: real (52.28%)  [WRONG]
#   > File: 114_102_36.png | True: fake | Predicted: real (50.09%)  [WRONG]
#   > File: 084_042_17.png | True: fake | Predicted: fake (91.85%)  [CORRECT]
#   > File: 121_093_2.png | True: fake | Predicted: fake (95.49%)  [CORRECT]
#   > File: 095_053_5.png | True: fake | Predicted: fake (59.68%)  [CORRECT]
#   > File: 114_102_5.png | True: fake | Predicted: real (51.49%)  [WRONG]
#   > File: 088_060_6.png | True: fake | Predicted: real (51.91%)  [WRONG]
#   > File: 076_079_6.png | True: fake | Predicted: fake (91.56%)  [CORRECT]
#   > File: 103_082_17.png | True: fake | Predicted: fake (53.32%)  [CORRECT]
#   > File: 073_024_6.png | True: fake | Predicted: fake (51.19%)  [CORRECT]
#   > File: 075_977_15.png | True: fake | Predicted: fake (77.79%)  [CORRECT]
#   > File: 075_977_18.png | True: fake | Predicted: fake (93.99%)  [CORRECT]
#   > File: 077_100_6.png | True: fake | Predicted: real (51.13%)  [WRONG]
#   > File: 096_101_15.png | True: fake | Predicted: fake (93.13%)  [CORRECT]
#   > File: 089_065_7.png | True: fake | Predicted: fake (89.79%)  [CORRECT]
#   > File: 114_102_46.png | True: fake | Predicted: real (52.22%)  [WRONG]
#   > File: 087_081_1.png | True: fake | Predicted: fake (63.91%)  [CORRECT]
#   > File: 088_060_13.png | True: fake | Predicted: fake (86.53%)  [CORRECT]
#   > File: 080_061_3.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 124_085_5.png | True: fake | Predicted: fake (72.92%)  [CORRECT]
#   > File: 107_109_8.png | True: fake | Predicted: fake (53.38%)  [CORRECT]
#   > File: 093_121_2.png | True: fake | Predicted: fake (50.26%)  [CORRECT]
#   > File: 101_096_0.png | True: fake | Predicted: fake (96.81%)  [CORRECT]
#   > File: 079_076_0.png | True: fake | Predicted: fake (90.86%)  [CORRECT]
#   > File: 106_198_11.png | True: fake | Predicted: fake (73.49%)  [CORRECT]
#   > File: 096_101_0.png | True: fake | Predicted: fake (65.39%)  [CORRECT]
#   > File: 107_109_17.png | True: fake | Predicted: fake (76.57%)  [CORRECT]
#   > File: 087_081_3.png | True: fake | Predicted: fake (66.48%)  [CORRECT]
#   > File: 078_955_17.png | True: fake | Predicted: fake (86.27%)  [CORRECT]
#   > File: 113_983_22.png | True: fake | Predicted: fake (96.32%)  [CORRECT]
#   > File: 107_109_3.png | True: fake | Predicted: fake (83.27%)  [CORRECT]
#   > File: 114_102_13.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 089_065_12.png | True: fake | Predicted: fake (95.15%)  [CORRECT]
#   > File: 122_144_7.png | True: fake | Predicted: fake (95.12%)  [CORRECT]
#   > File: 073_024_26.png | True: fake | Predicted: fake (50.53%)  [CORRECT]
#   > File: 092_098_3.png | True: fake | Predicted: fake (52.54%)  [CORRECT]
#   > File: 114_102_15.png | True: fake | Predicted: fake (53.50%)  [CORRECT]
#   > File: 100_077_3.png | True: fake | Predicted: fake (89.83%)  [CORRECT]
#   > File: 103_082_6.png | True: fake | Predicted: fake (64.26%)  [CORRECT]
#   > File: 114_102_11.png | True: fake | Predicted: fake (62.15%)  [CORRECT]
#   > File: 125_038_2.png | True: fake | Predicted: fake (69.00%)  [CORRECT]
#   > File: 067_025_11.png | True: fake | Predicted: fake (99.67%)  [CORRECT]
#   > File: 104_126_2.png | True: fake | Predicted: fake (90.42%)  [CORRECT]
#   > File: 090_086_5.png | True: fake | Predicted: fake (77.95%)  [CORRECT]
#   > File: 111_094_16.png | True: fake | Predicted: fake (52.98%)  [CORRECT]
#   > File: 126_104_7.png | True: fake | Predicted: fake (84.93%)  [CORRECT]
#   > File: 073_024_12.png | True: fake | Predicted: fake (50.62%)  [CORRECT]
#   > File: 105_180_8.png | True: fake | Predicted: fake (73.38%)  [CORRECT]
#   > File: 069_961_22.png | True: fake | Predicted: fake (95.02%)  [CORRECT]
#   > File: 088_060_20.png | True: fake | Predicted: fake (65.72%)  [CORRECT]
#   > File: 121_093_13.png | True: fake | Predicted: fake (82.64%)  [CORRECT]
#   > File: 113_983_25.png | True: fake | Predicted: fake (92.34%)  [CORRECT]
#   > File: 076_079_7.png | True: fake | Predicted: fake (93.36%)  [CORRECT]
#   > File: 125_038_15.png | True: fake | Predicted: fake (64.96%)  [CORRECT]
#   > File: 113_983_21.png | True: fake | Predicted: fake (96.55%)  [CORRECT]
#   > File: 073_024_17.png | True: fake | Predicted: fake (50.68%)  [CORRECT]
#   > File: 103_082_1.png | True: fake | Predicted: fake (57.80%)  [CORRECT]
#   > File: 120_118_9.png | True: fake | Predicted: fake (57.29%)  [CORRECT]
#   > File: 081_087_27.png | True: fake | Predicted: fake (74.95%)  [CORRECT]
#   > File: 111_094_8.png | True: fake | Predicted: fake (72.79%)  [CORRECT]
#   > File: 069_961_1.png | True: fake | Predicted: fake (92.58%)  [CORRECT]
#   > File: 121_093_10.png | True: fake | Predicted: fake (86.65%)  [CORRECT]
#   > File: 067_025_15.png | True: fake | Predicted: fake (99.42%)  [CORRECT]
#   > File: 099_295_18.png | True: fake | Predicted: fake (89.41%)  [CORRECT]
#   > File: 115_939_10.png | True: fake | Predicted: fake (64.21%)  [CORRECT]
#   > File: 086_090_12.png | True: fake | Predicted: fake (78.03%)  [CORRECT]
#   > File: 076_079_1.png | True: fake | Predicted: fake (77.94%)  [CORRECT]
#   > File: 125_038_16.png | True: fake | Predicted: fake (62.60%)  [CORRECT]
#   > File: 103_082_12.png | True: fake | Predicted: real (50.40%)  [WRONG]
#   > File: 118_120_9.png | True: fake | Predicted: real (52.91%)  [WRONG]
#   > File: 120_118_1.png | True: fake | Predicted: real (52.11%)  [WRONG]
#   > File: 108_052_4.png | True: fake | Predicted: fake (89.81%)  [CORRECT]
#   > File: 071_054_14.png | True: fake | Predicted: real (52.35%)  [WRONG]
#   > File: 098_092_10.png | True: fake | Predicted: fake (83.76%)  [CORRECT]
#   > File: 124_085_4.png | True: fake | Predicted: fake (75.95%)  [CORRECT]
#   > File: 075_977_5.png | True: fake | Predicted: fake (83.16%)  [CORRECT]
#   > File: 088_060_24.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 086_090_8.png | True: fake | Predicted: fake (89.96%)  [CORRECT]
#   > File: 104_126_6.png | True: fake | Predicted: fake (74.57%)  [CORRECT]
#   > File: 127_129_5.png | True: fake | Predicted: fake (50.24%)  [CORRECT]
#   > File: 119_123_9.png | True: fake | Predicted: fake (96.10%)  [CORRECT]
#   > File: 077_100_7.png | True: fake | Predicted: fake (55.29%)  [CORRECT]
#   > File: 068_028_3.png | True: fake | Predicted: fake (90.13%)  [CORRECT]
#   > File: 074_825_3.png | True: fake | Predicted: fake (62.30%)  [CORRECT]
#   > File: 086_090_22.png | True: fake | Predicted: fake (84.50%)  [CORRECT]
#   > File: 095_053_0.png | True: fake | Predicted: real (52.09%)  [WRONG]
#   > File: 069_961_14.png | True: fake | Predicted: fake (91.08%)  [CORRECT]
#   > File: 088_060_12.png | True: fake | Predicted: fake (75.50%)  [CORRECT]
#   > File: 077_100_12.png | True: fake | Predicted: fake (50.61%)  [CORRECT]
#   > File: 073_024_20.png | True: fake | Predicted: fake (52.77%)  [CORRECT]
#   > File: 127_129_20.png | True: fake | Predicted: real (52.46%)  [WRONG]
#   > File: 078_955_13.png | True: fake | Predicted: fake (81.54%)  [CORRECT]
#   > File: 077_100_8.png | True: fake | Predicted: fake (58.00%)  [CORRECT]
#   > File: 072_037_4.png | True: fake | Predicted: fake (96.20%)  [CORRECT]
#   > File: 069_961_6.png | True: fake | Predicted: fake (95.14%)  [CORRECT]
#   > File: 082_103_5.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 092_098_17.png | True: fake | Predicted: fake (55.45%)  [CORRECT]
#   > File: 097_033_1.png | True: fake | Predicted: real (73.02%)  [WRONG]
#   > File: 091_116_4.png | True: fake | Predicted: fake (83.63%)  [CORRECT]
#   > File: 106_198_5.png | True: fake | Predicted: fake (79.76%)  [CORRECT]
#   > File: 076_079_9.png | True: fake | Predicted: fake (81.93%)  [CORRECT]
#   > File: 117_217_1.png | True: fake | Predicted: fake (59.50%)  [CORRECT]
#   > File: 122_144_5.png | True: fake | Predicted: fake (82.07%)  [CORRECT]
#   > File: 087_081_10.png | True: fake | Predicted: fake (76.64%)  [CORRECT]
#   > File: 070_057_0.png | True: fake | Predicted: fake (80.24%)  [CORRECT]
#   > File: 095_053_35.png | True: fake | Predicted: fake (79.95%)  [CORRECT]
#   > File: 108_052_0.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 094_111_19.png | True: fake | Predicted: fake (67.55%)  [CORRECT]
#   > File: 104_126_10.png | True: fake | Predicted: fake (74.27%)  [CORRECT]
#   > File: 078_955_11.png | True: fake | Predicted: fake (90.57%)  [CORRECT]
#   > File: 107_109_7.png | True: fake | Predicted: fake (53.46%)  [CORRECT]
#   > File: 109_107_0.png | True: fake | Predicted: fake (96.39%)  [CORRECT]
#   > File: 081_087_14.png | True: fake | Predicted: fake (75.89%)  [CORRECT]
#   > File: 117_217_21.png | True: fake | Predicted: fake (52.30%)  [CORRECT]
#   > File: 099_295_19.png | True: fake | Predicted: fake (96.25%)  [CORRECT]
#   > File: 124_085_2.png | True: fake | Predicted: fake (93.83%)  [CORRECT]
#   > File: 121_093_16.png | True: fake | Predicted: fake (75.74%)  [CORRECT]
#   > File: 092_098_6.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 099_295_23.png | True: fake | Predicted: fake (88.70%)  [CORRECT]
#   > File: 101_096_36.png | True: fake | Predicted: fake (99.77%)  [CORRECT]
#   > File: 082_103_16.png | True: fake | Predicted: fake (97.28%)  [CORRECT]
#   > File: 099_295_16.png | True: fake | Predicted: fake (81.80%)  [CORRECT]
#   > File: 127_129_21.png | True: fake | Predicted: fake (56.69%)  [CORRECT]
#   > File: 102_114_9.png | True: fake | Predicted: fake (85.75%)  [CORRECT]
#   > File: 097_033_2.png | True: fake | Predicted: real (68.75%)  [WRONG]
#   > File: 095_053_32.png | True: fake | Predicted: fake (84.47%)  [CORRECT]
#   > File: 098_092_8.png | True: fake | Predicted: fake (76.95%)  [CORRECT]
#   > File: 079_076_10.png | True: fake | Predicted: fake (92.09%)  [CORRECT]
#   > File: 079_076_12.png | True: fake | Predicted: fake (85.38%)  [CORRECT]
#   > File: 070_057_2.png | True: fake | Predicted: fake (88.89%)  [CORRECT]
#   > File: 071_054_12.png | True: fake | Predicted: fake (67.58%)  [CORRECT]
#   > File: 114_102_38.png | True: fake | Predicted: real (52.05%)  [WRONG]
#   > File: 100_077_6.png | True: fake | Predicted: fake (74.58%)  [CORRECT]
#   > File: 078_955_20.png | True: fake | Predicted: fake (77.84%)  [CORRECT]
#   > File: 081_087_44.png | True: fake | Predicted: fake (77.90%)  [CORRECT]
#   > File: 109_107_7.png | True: fake | Predicted: fake (97.41%)  [CORRECT]
#   > File: 085_124_3.png | True: fake | Predicted: fake (67.27%)  [CORRECT]
#   > File: 084_042_23.png | True: fake | Predicted: fake (94.76%)  [CORRECT]
#   > File: 069_961_17.png | True: fake | Predicted: fake (97.67%)  [CORRECT]
#   > File: 095_053_8.png | True: fake | Predicted: fake (78.62%)  [CORRECT]
#   > File: 104_126_7.png | True: fake | Predicted: fake (57.68%)  [CORRECT]
#   > File: 102_114_12.png | True: fake | Predicted: fake (87.31%)  [CORRECT]
#   > File: 088_060_10.png | True: fake | Predicted: fake (78.50%)  [CORRECT]
#   > File: 086_090_1.png | True: fake | Predicted: fake (87.24%)  [CORRECT]
#   > File: 107_109_5.png | True: fake | Predicted: fake (55.64%)  [CORRECT]
#   > File: 113_983_29.png | True: fake | Predicted: fake (96.92%)  [CORRECT]
#   > File: 122_144_4.png | True: fake | Predicted: fake (91.86%)  [CORRECT]
#   > File: 101_096_9.png | True: fake | Predicted: fake (99.88%)  [CORRECT]
#   > File: 073_024_13.png | True: fake | Predicted: fake (50.03%)  [CORRECT]
#   > File: 095_053_6.png | True: fake | Predicted: fake (66.74%)  [CORRECT]
#   > File: 112_892_5.png | True: fake | Predicted: fake (87.10%)  [CORRECT]
#   > File: 082_103_13.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 079_076_13.png | True: fake | Predicted: fake (89.24%)  [CORRECT]
#   > File: 086_090_7.png | True: fake | Predicted: fake (92.78%)  [CORRECT]
#   > File: 119_123_12.png | True: fake | Predicted: fake (77.01%)  [CORRECT]
#   > File: 087_081_4.png | True: fake | Predicted: fake (65.37%)  [CORRECT]
#   > File: 115_939_9.png | True: fake | Predicted: fake (58.14%)  [CORRECT]
#   > File: 086_090_5.png | True: fake | Predicted: fake (91.01%)  [CORRECT]
#   > File: 099_295_10.png | True: fake | Predicted: fake (93.68%)  [CORRECT]
#   > File: 096_101_2.png | True: fake | Predicted: fake (93.92%)  [CORRECT]
#   > File: 105_180_6.png | True: fake | Predicted: real (51.09%)  [WRONG]
#   > File: 084_042_14.png | True: fake | Predicted: fake (90.64%)  [CORRECT]
#   > File: 080_061_0.png | True: fake | Predicted: fake (56.83%)  [CORRECT]
#   > File: 101_096_22.png | True: fake | Predicted: fake (99.89%)  [CORRECT]
#   > File: 121_093_4.png | True: fake | Predicted: fake (83.90%)  [CORRECT]
#   > File: 114_102_37.png | True: fake | Predicted: real (50.24%)  [WRONG]
#   > File: 086_090_17.png | True: fake | Predicted: fake (92.75%)  [CORRECT]
#   > File: 073_024_25.png | True: fake | Predicted: fake (57.09%)  [CORRECT]
#   > File: 081_087_29.png | True: fake | Predicted: fake (65.35%)  [CORRECT]
#   > File: 101_096_7.png | True: fake | Predicted: fake (99.48%)  [CORRECT]
#   > File: 084_042_20.png | True: fake | Predicted: fake (85.49%)  [CORRECT]
#   > File: 108_052_8.png | True: fake | Predicted: fake (88.20%)  [CORRECT]
#   > File: 114_102_31.png | True: fake | Predicted: fake (59.08%)  [CORRECT]
#   > File: 114_102_24.png | True: fake | Predicted: fake (62.84%)  [CORRECT]
#   > File: 113_983_8.png | True: fake | Predicted: fake (97.76%)  [CORRECT]
#   > File: 107_109_2.png | True: fake | Predicted: fake (65.82%)  [CORRECT]
#   > File: 074_825_5.png | True: fake | Predicted: fake (63.16%)  [CORRECT]
#   > File: 073_024_3.png | True: fake | Predicted: real (53.30%)  [WRONG]
#   > File: 073_024_24.png | True: fake | Predicted: fake (57.22%)  [CORRECT]
#   > File: 089_065_1.png | True: fake | Predicted: fake (85.94%)  [CORRECT]
#   > File: 101_096_4.png | True: fake | Predicted: fake (96.13%)  [CORRECT]
#   > File: 086_090_30.png | True: fake | Predicted: fake (95.05%)  [CORRECT]
#   > File: 121_093_21.png | True: fake | Predicted: fake (96.14%)  [CORRECT]
#   > File: 080_061_13.png | True: fake | Predicted: fake (75.45%)  [CORRECT]
#   > File: 069_961_21.png | True: fake | Predicted: fake (87.81%)  [CORRECT]
#   > File: 095_053_4.png | True: fake | Predicted: real (50.90%)  [WRONG]
#   > File: 104_126_0.png | True: fake | Predicted: fake (62.75%)  [CORRECT]
#   > File: 081_087_18.png | True: fake | Predicted: fake (77.30%)  [CORRECT]
#   > File: 112_892_11.png | True: fake | Predicted: fake (82.44%)  [CORRECT]
#   > File: 122_144_6.png | True: fake | Predicted: fake (90.06%)  [CORRECT]
#   > File: 120_118_14.png | True: fake | Predicted: real (51.63%)  [WRONG]
#   > File: 114_102_7.png | True: fake | Predicted: real (51.27%)  [WRONG]
#   > File: 083_213_2.png | True: fake | Predicted: fake (94.41%)  [CORRECT]
#   > File: 075_977_3.png | True: fake | Predicted: fake (88.55%)  [CORRECT]
#   > File: 114_102_19.png | True: fake | Predicted: fake (56.74%)  [CORRECT]
#   > File: 097_033_13.png | True: fake | Predicted: real (81.47%)  [WRONG]
#   > File: 121_093_14.png | True: fake | Predicted: fake (75.84%)  [CORRECT]
#   > File: 071_054_6.png | True: fake | Predicted: real (72.69%)  [WRONG]
#   > File: 095_053_28.png | True: fake | Predicted: fake (85.60%)  [CORRECT]
#   > File: 113_983_15.png | True: fake | Predicted: fake (97.73%)  [CORRECT]
#   > File: 080_061_18.png | True: fake | Predicted: real (51.14%)  [WRONG]
#   > File: 095_053_17.png | True: fake | Predicted: fake (76.40%)  [CORRECT]
#   > File: 122_144_2.png | True: fake | Predicted: fake (78.35%)  [CORRECT]
#   > File: 093_121_4.png | True: fake | Predicted: fake (69.95%)  [CORRECT]
#   > File: 071_054_3.png | True: fake | Predicted: real (50.99%)  [WRONG]
#   > File: 080_061_12.png | True: fake | Predicted: fake (67.16%)  [CORRECT]
#   > File: 125_038_12.png | True: fake | Predicted: real (50.72%)  [WRONG]
#   > File: 094_111_8.png | True: fake | Predicted: fake (89.94%)  [CORRECT]
#   > File: 083_213_12.png | True: fake | Predicted: fake (93.59%)  [CORRECT]
#   > File: 096_101_10.png | True: fake | Predicted: fake (94.27%)  [CORRECT]
#   > File: 087_081_6.png | True: fake | Predicted: fake (55.57%)  [CORRECT]
#   > File: 115_939_6.png | True: fake | Predicted: fake (66.77%)  [CORRECT]
#   > File: 096_101_7.png | True: fake | Predicted: fake (63.84%)  [CORRECT]
#   > File: 114_102_16.png | True: fake | Predicted: fake (50.12%)  [CORRECT]
#   > File: 099_295_15.png | True: fake | Predicted: fake (84.41%)  [CORRECT]
#   > File: 081_087_25.png | True: fake | Predicted: fake (74.70%)  [CORRECT]
#   > File: 119_123_13.png | True: fake | Predicted: fake (98.94%)  [CORRECT]
#   > File: 101_096_27.png | True: fake | Predicted: fake (98.84%)  [CORRECT]
#   > File: 083_213_13.png | True: fake | Predicted: fake (93.66%)  [CORRECT]
#   > File: 070_057_12.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 072_037_5.png | True: fake | Predicted: fake (86.85%)  [CORRECT]
#   > File: 114_102_2.png | True: fake | Predicted: fake (51.73%)  [CORRECT]
#   > File: 107_109_21.png | True: fake | Predicted: fake (70.82%)  [CORRECT]
#   > File: 078_955_10.png | True: fake | Predicted: fake (82.13%)  [CORRECT]
#   > File: 076_079_2.png | True: fake | Predicted: fake (61.57%)  [CORRECT]
#   > File: 087_081_9.png | True: fake | Predicted: fake (70.28%)  [CORRECT]
#   > File: 095_053_3.png | True: fake | Predicted: fake (63.46%)  [CORRECT]
#   > File: 101_096_26.png | True: fake | Predicted: fake (97.97%)  [CORRECT]
#   > File: 090_086_11.png | True: fake | Predicted: fake (84.45%)  [CORRECT]
#   > File: 105_180_2.png | True: fake | Predicted: fake (51.04%)  [CORRECT]
#   > File: 074_825_11.png | True: fake | Predicted: fake (53.77%)  [CORRECT]
#   > File: 080_061_2.png | True: fake | Predicted: real (52.40%)  [WRONG]
#   > File: 078_955_5.png | True: fake | Predicted: fake (84.97%)  [CORRECT]
#   > File: 068_028_5.png | True: fake | Predicted: fake (81.81%)  [CORRECT]
#   > File: 077_100_11.png | True: fake | Predicted: fake (71.17%)  [CORRECT]
#   > File: 106_198_2.png | True: fake | Predicted: fake (88.21%)  [CORRECT]
#   > File: 127_129_14.png | True: fake | Predicted: fake (65.67%)  [CORRECT]
#   > File: 116_091_6.png | True: fake | Predicted: fake (79.29%)  [CORRECT]
#   > File: 095_053_7.png | True: fake | Predicted: fake (77.39%)  [CORRECT]
#   > File: 099_295_9.png | True: fake | Predicted: fake (84.63%)  [CORRECT]
#   > File: 100_077_15.png | True: fake | Predicted: fake (78.18%)  [CORRECT]
#   > File: 094_111_24.png | True: fake | Predicted: fake (69.88%)  [CORRECT]
#   > File: 099_295_13.png | True: fake | Predicted: fake (64.77%)  [CORRECT]
#   > File: 098_092_0.png | True: fake | Predicted: fake (62.99%)  [CORRECT]
#   > File: 107_109_0.png | True: fake | Predicted: real (50.22%)  [WRONG]
#   > File: 112_892_0.png | True: fake | Predicted: fake (80.76%)  [CORRECT]
#   > File: 114_102_28.png | True: fake | Predicted: fake (62.37%)  [CORRECT]
#   > File: 095_053_15.png | True: fake | Predicted: fake (64.02%)  [CORRECT]
#   > File: 127_129_9.png | True: fake | Predicted: fake (63.64%)  [CORRECT]
#   > File: 078_955_16.png | True: fake | Predicted: fake (86.19%)  [CORRECT]
#   > File: 069_961_7.png | True: fake | Predicted: fake (94.78%)  [CORRECT]
#   > File: 086_090_27.png | True: fake | Predicted: fake (81.08%)  [CORRECT]
#   > File: 113_983_33.png | True: fake | Predicted: fake (97.02%)  [CORRECT]
#   > File: 071_054_0.png | True: fake | Predicted: real (53.11%)  [WRONG]
#   > File: 111_094_10.png | True: fake | Predicted: real (50.93%)  [WRONG]
#   > File: 079_076_8.png | True: fake | Predicted: fake (93.23%)  [CORRECT]
#   > File: 107_109_13.png | True: fake | Predicted: fake (90.57%)  [CORRECT]
#   > File: 089_065_2.png | True: fake | Predicted: fake (91.52%)  [CORRECT]
#   > File: 101_096_21.png | True: fake | Predicted: fake (97.31%)  [CORRECT]
#   > File: 113_983_4.png | True: fake | Predicted: fake (94.27%)  [CORRECT]
#   > File: 081_087_9.png | True: fake | Predicted: fake (73.36%)  [CORRECT]
#   > File: 113_983_27.png | True: fake | Predicted: fake (93.60%)  [CORRECT]
#   > File: 074_825_12.png | True: fake | Predicted: fake (57.73%)  [CORRECT]
#   > File: 074_825_13.png | True: fake | Predicted: real (50.41%)  [WRONG]
#   > File: 109_107_10.png | True: fake | Predicted: fake (97.39%)  [CORRECT]
#   > File: 081_087_20.png | True: fake | Predicted: fake (82.28%)  [CORRECT]
#   > File: 097_033_5.png | True: fake | Predicted: real (54.86%)  [WRONG]
#   > File: 089_065_9.png | True: fake | Predicted: fake (79.39%)  [CORRECT]
#   > File: 068_028_1.png | True: fake | Predicted: fake (87.66%)  [CORRECT]
#   > File: 088_060_11.png | True: fake | Predicted: real (51.91%)  [WRONG]
#   > File: 091_116_11.png | True: fake | Predicted: fake (88.57%)  [CORRECT]
#   > File: 095_053_18.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 088_060_18.png | True: fake | Predicted: real (61.66%)  [WRONG]
#   > File: 124_085_12.png | True: fake | Predicted: fake (51.41%)  [CORRECT]
#   > File: 127_129_0.png | True: fake | Predicted: real (51.71%)  [WRONG]
#   > File: 069_961_8.png | True: fake | Predicted: fake (94.97%)  [CORRECT]
#   > File: 077_100_21.png | True: fake | Predicted: fake (55.38%)  [CORRECT]
#   > File: 118_120_7.png | True: fake | Predicted: real (52.26%)  [WRONG]
#   > File: 103_082_10.png | True: fake | Predicted: fake (67.79%)  [CORRECT]
#   > File: 075_977_11.png | True: fake | Predicted: fake (82.38%)  [CORRECT]
#   > File: 102_114_13.png | True: fake | Predicted: fake (95.54%)  [CORRECT]
#   > File: 113_983_0.png | True: fake | Predicted: fake (92.96%)  [CORRECT]
#   > File: 112_892_6.png | True: fake | Predicted: fake (62.12%)  [CORRECT]
#   > File: 107_109_4.png | True: fake | Predicted: fake (75.63%)  [CORRECT]
#   > File: 103_082_20.png | True: fake | Predicted: real (52.25%)  [WRONG]
#   > File: 100_077_5.png | True: fake | Predicted: fake (80.86%)  [CORRECT]
#   > File: 068_028_2.png | True: fake | Predicted: fake (74.60%)  [CORRECT]
#   > File: 117_217_3.png | True: fake | Predicted: fake (55.86%)  [CORRECT]
#   > File: 127_129_22.png | True: fake | Predicted: real (52.01%)  [WRONG]
#   > File: 121_093_0.png | True: fake | Predicted: fake (97.72%)  [CORRECT]
#   > File: 081_087_2.png | True: fake | Predicted: fake (69.37%)  [CORRECT]
#   > File: 102_114_11.png | True: fake | Predicted: fake (95.32%)  [CORRECT]
#   > File: 124_085_11.png | True: fake | Predicted: fake (60.09%)  [CORRECT]
#   > File: 095_053_2.png | True: fake | Predicted: fake (56.20%)  [CORRECT]
#   > File: 108_052_5.png | True: fake | Predicted: fake (64.52%)  [CORRECT]
#   > File: 114_102_48.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 077_100_14.png | True: fake | Predicted: fake (56.37%)  [CORRECT]
#   > File: 085_124_5.png | True: fake | Predicted: fake (67.00%)  [CORRECT]
#   > File: 117_217_7.png | True: fake | Predicted: fake (69.11%)  [CORRECT]
#   > File: 095_053_13.png | True: fake | Predicted: fake (59.54%)  [CORRECT]
#   > File: 111_094_7.png | True: fake | Predicted: fake (50.00%)  [CORRECT]
#   > File: 094_111_25.png | True: fake | Predicted: fake (83.43%)  [CORRECT]
#   > File: 112_892_12.png | True: fake | Predicted: fake (78.78%)  [CORRECT]
#   > File: 069_961_5.png | True: fake | Predicted: fake (90.40%)  [CORRECT]
#   > File: 105_180_9.png | True: fake | Predicted: fake (66.95%)  [CORRECT]
#   > File: 110_043_5.png | True: fake | Predicted: fake (77.26%)  [CORRECT]
#   > File: 082_103_1.png | True: fake | Predicted: fake (91.92%)  [CORRECT]
#   > File: 101_096_31.png | True: fake | Predicted: fake (94.08%)  [CORRECT]
#   > File: 069_961_15.png | True: fake | Predicted: fake (97.12%)  [CORRECT]
#   > File: 103_082_19.png | True: fake | Predicted: fake (77.76%)  [CORRECT]
#   > File: 125_038_10.png | True: fake | Predicted: fake (64.79%)  [CORRECT]
#   > File: 124_085_9.png | True: fake | Predicted: fake (68.53%)  [CORRECT]
#   > File: 114_102_18.png | True: fake | Predicted: fake (54.07%)  [CORRECT]
#   > File: 096_101_5.png | True: fake | Predicted: fake (88.12%)  [CORRECT]
#   > File: 115_939_1.png | True: fake | Predicted: fake (52.36%)  [CORRECT]
#   > File: 116_091_7.png | True: fake | Predicted: fake (70.19%)  [CORRECT]
#   > File: 099_295_1.png | True: fake | Predicted: fake (86.02%)  [CORRECT]
#   > File: 116_091_2.png | True: fake | Predicted: fake (73.21%)  [CORRECT]
#   > File: 080_061_1.png | True: fake | Predicted: real (51.62%)  [WRONG]
#   > File: 085_124_2.png | True: fake | Predicted: fake (68.67%)  [CORRECT]
#   > File: 126_104_3.png | True: fake | Predicted: fake (57.27%)  [CORRECT]
#   > File: 089_065_19.png | True: fake | Predicted: fake (76.56%)  [CORRECT]
#   > File: 127_129_10.png | True: fake | Predicted: real (52.18%)  [WRONG]
#   > File: 115_939_7.png | True: fake | Predicted: fake (63.01%)  [CORRECT]
#   > File: 071_054_1.png | True: fake | Predicted: fake (59.88%)  [CORRECT]
#   > File: 118_120_12.png | True: fake | Predicted: real (52.00%)  [WRONG]
#   > File: 082_103_8.png | True: fake | Predicted: fake (94.67%)  [CORRECT]
#   > File: 086_090_20.png | True: fake | Predicted: fake (79.79%)  [CORRECT]
#   > File: 091_116_19.png | True: fake | Predicted: fake (93.66%)  [CORRECT]
#   > File: 099_295_12.png | True: fake | Predicted: fake (77.16%)  [CORRECT]
#   > File: 067_025_16.png | True: fake | Predicted: fake (99.88%)  [CORRECT]
#   > File: 094_111_20.png | True: fake | Predicted: fake (80.54%)  [CORRECT]
#   > File: 078_955_2.png | True: fake | Predicted: fake (81.57%)  [CORRECT]
#   > File: 090_086_3.png | True: fake | Predicted: fake (83.05%)  [CORRECT]
#   > File: 101_096_1.png | True: fake | Predicted: fake (99.77%)  [CORRECT]
#   > File: 073_024_19.png | True: fake | Predicted: fake (53.06%)  [CORRECT]
#   > File: 125_038_7.png | True: fake | Predicted: fake (58.06%)  [CORRECT]
#   > File: 097_033_14.png | True: fake | Predicted: real (61.38%)  [WRONG]
#   > File: 094_111_0.png | True: fake | Predicted: fake (63.92%)  [CORRECT]
#   > File: 073_024_7.png | True: fake | Predicted: real (50.36%)  [WRONG]
#   > File: 080_061_15.png | True: fake | Predicted: fake (70.47%)  [CORRECT]
#   > File: 095_053_14.png | True: fake | Predicted: fake (77.55%)  [CORRECT]
#   > File: 105_180_0.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 068_028_8.png | True: fake | Predicted: fake (98.19%)  [CORRECT]
#   > File: 085_124_6.png | True: fake | Predicted: fake (64.95%)  [CORRECT]
#   > File: 080_061_14.png | True: fake | Predicted: fake (54.88%)  [CORRECT]
#   > File: 068_028_9.png | True: fake | Predicted: fake (98.54%)  [CORRECT]
#   > File: 121_093_17.png | True: fake | Predicted: fake (66.64%)  [CORRECT]
#   > File: 117_217_16.png | True: fake | Predicted: fake (55.00%)  [CORRECT]
#   > File: 117_217_12.png | True: fake | Predicted: fake (59.67%)  [CORRECT]
#   > File: 078_955_7.png | True: fake | Predicted: fake (83.31%)  [CORRECT]
#   > File: 117_217_8.png | True: fake | Predicted: fake (89.87%)  [CORRECT]
#   > File: 083_213_1.png | True: fake | Predicted: fake (91.28%)  [CORRECT]
#   > File: 114_102_10.png | True: fake | Predicted: fake (59.86%)  [CORRECT]
#   > File: 080_061_10.png | True: fake | Predicted: real (52.19%)  [WRONG]
#   > File: 089_065_25.png | True: fake | Predicted: fake (92.09%)  [CORRECT]
#   > File: 091_116_20.png | True: fake | Predicted: fake (58.83%)  [CORRECT]
#   > File: 104_126_4.png | True: fake | Predicted: fake (84.85%)  [CORRECT]
#   > File: 105_180_5.png | True: fake | Predicted: fake (74.29%)  [CORRECT]
#   > File: 102_114_1.png | True: fake | Predicted: fake (79.35%)  [CORRECT]
#   > File: 095_053_30.png | True: fake | Predicted: fake (51.75%)  [CORRECT]
#   > File: 113_983_10.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 094_111_23.png | True: fake | Predicted: fake (84.95%)  [CORRECT]
#   > File: 083_213_0.png | True: fake | Predicted: fake (92.49%)  [CORRECT]
#   > File: 119_123_5.png | True: fake | Predicted: fake (97.81%)  [CORRECT]
#   > File: 083_213_6.png | True: fake | Predicted: fake (89.88%)  [CORRECT]
#   > File: 086_090_4.png | True: fake | Predicted: fake (97.20%)  [CORRECT]
#   > File: 069_961_0.png | True: fake | Predicted: fake (91.86%)  [CORRECT]
#   > File: 081_087_36.png | True: fake | Predicted: fake (56.91%)  [CORRECT]
#   > File: 110_043_3.png | True: fake | Predicted: fake (64.17%)  [CORRECT]
#   > File: 101_096_13.png | True: fake | Predicted: fake (96.11%)  [CORRECT]
#   > File: 112_892_3.png | True: fake | Predicted: fake (69.68%)  [CORRECT]
#   > File: 095_053_22.png | True: fake | Predicted: fake (58.46%)  [CORRECT]
#   > File: 094_111_6.png | True: fake | Predicted: fake (81.59%)  [CORRECT]
#   > File: 089_065_28.png | True: fake | Predicted: fake (76.70%)  [CORRECT]
#   > File: 084_042_1.png | True: fake | Predicted: fake (93.37%)  [CORRECT]
#   > File: 084_042_6.png | True: fake | Predicted: fake (92.76%)  [CORRECT]
#   > File: 094_111_12.png | True: fake | Predicted: fake (67.47%)  [CORRECT]
#   > File: 108_052_6.png | True: fake | Predicted: fake (89.33%)  [CORRECT]
#   > File: 067_025_4.png | True: fake | Predicted: fake (92.82%)  [CORRECT]
#   > File: 091_116_10.png | True: fake | Predicted: fake (90.19%)  [CORRECT]
#   > File: 094_111_13.png | True: fake | Predicted: real (52.42%)  [WRONG]
#   > File: 119_123_2.png | True: fake | Predicted: fake (96.61%)  [CORRECT]
#   > File: 114_102_30.png | True: fake | Predicted: fake (65.26%)  [CORRECT]
#   > File: 123_119_11.png | True: fake | Predicted: real (50.68%)  [WRONG]
#   > File: 089_065_24.png | True: fake | Predicted: fake (85.90%)  [CORRECT]
#   > File: 111_094_5.png | True: fake | Predicted: fake (66.01%)  [CORRECT]
#   > File: 123_119_13.png | True: fake | Predicted: fake (59.47%)  [CORRECT]
#   > File: 100_077_2.png | True: fake | Predicted: fake (53.13%)  [CORRECT]
#   > File: 103_082_4.png | True: fake | Predicted: fake (89.12%)  [CORRECT]
#   > File: 092_098_11.png | True: fake | Predicted: real (51.38%)  [WRONG]
#   > File: 084_042_16.png | True: fake | Predicted: fake (92.00%)  [CORRECT]
#   > File: 093_121_6.png | True: fake | Predicted: fake (73.75%)  [CORRECT]
#   > File: 071_054_2.png | True: fake | Predicted: fake (50.94%)  [CORRECT]
#   > File: 082_103_4.png | True: fake | Predicted: fake (86.54%)  [CORRECT]
#   > File: 090_086_22.png | True: fake | Predicted: fake (67.11%)  [CORRECT]
#   > File: 114_102_44.png | True: fake | Predicted: real (52.27%)  [WRONG]
#   > File: 086_090_25.png | True: fake | Predicted: fake (95.14%)  [CORRECT]
#   > File: 094_111_18.png | True: fake | Predicted: fake (75.05%)  [CORRECT]
#   > File: 114_102_41.png | True: fake | Predicted: real (52.36%)  [WRONG]
#   > File: 127_129_19.png | True: fake | Predicted: fake (77.89%)  [CORRECT]
#   > File: 110_043_0.png | True: fake | Predicted: fake (57.75%)  [CORRECT]
#   > File: 126_104_1.png | True: fake | Predicted: fake (66.26%)  [CORRECT]
#   > File: 097_033_0.png | True: fake | Predicted: real (65.37%)  [WRONG]
#   > File: 092_098_8.png | True: fake | Predicted: fake (57.35%)  [CORRECT]
#   > File: 090_086_8.png | True: fake | Predicted: fake (92.08%)  [CORRECT]
#   > File: 102_114_8.png | True: fake | Predicted: fake (94.20%)  [CORRECT]
#   > File: 088_060_3.png | True: fake | Predicted: fake (63.24%)  [CORRECT]
#   > File: 115_939_2.png | True: fake | Predicted: fake (57.67%)  [CORRECT]
#   > File: 078_955_4.png | True: fake | Predicted: fake (71.11%)  [CORRECT]
#   > File: 103_082_21.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 085_124_10.png | True: fake | Predicted: fake (78.15%)  [CORRECT]
#   > File: 120_118_6.png | True: fake | Predicted: fake (51.53%)  [CORRECT]
#   > File: 113_983_24.png | True: fake | Predicted: fake (92.93%)  [CORRECT]
#   > File: 097_033_3.png | True: fake | Predicted: real (73.94%)  [WRONG]
#   > File: 090_086_4.png | True: fake | Predicted: fake (94.29%)  [CORRECT]
#   > File: 075_977_17.png | True: fake | Predicted: fake (91.07%)  [CORRECT]
#   > File: 110_043_13.png | True: fake | Predicted: fake (52.85%)  [CORRECT]
#   > File: 092_098_9.png | True: fake | Predicted: fake (58.69%)  [CORRECT]
#   > File: 083_213_4.png | True: fake | Predicted: fake (89.42%)  [CORRECT]
#   > File: 121_093_20.png | True: fake | Predicted: fake (96.46%)  [CORRECT]
#   > File: 120_118_4.png | True: fake | Predicted: fake (52.06%)  [CORRECT]
#   > File: 094_111_11.png | True: fake | Predicted: real (52.88%)  [WRONG]
#   > File: 119_123_10.png | True: fake | Predicted: fake (97.95%)  [CORRECT]
#   > File: 069_961_9.png | True: fake | Predicted: fake (96.33%)  [CORRECT]
#   > File: 110_043_7.png | True: fake | Predicted: real (51.91%)  [WRONG]
#   > File: 111_094_4.png | True: fake | Predicted: fake (62.19%)  [CORRECT]
#   > File: 120_118_11.png | True: fake | Predicted: fake (73.13%)  [CORRECT]
#   > File: 099_295_8.png | True: fake | Predicted: fake (91.44%)  [CORRECT]
#   > File: 112_892_10.png | True: fake | Predicted: fake (83.69%)  [CORRECT]
#   > File: 111_094_0.png | True: fake | Predicted: real (51.93%)  [WRONG]
#   > File: 082_103_10.png | True: fake | Predicted: fake (92.99%)  [CORRECT]
#   > File: 073_024_5.png | True: fake | Predicted: fake (55.18%)  [CORRECT]
#   > File: 103_082_18.png | True: fake | Predicted: fake (55.48%)  [CORRECT]
#   > File: 087_081_0.png | True: fake | Predicted: fake (51.35%)  [CORRECT]
#   > File: 123_119_14.png | True: fake | Predicted: real (51.20%)  [WRONG]
#   > File: 119_123_3.png | True: fake | Predicted: fake (97.07%)  [CORRECT]
#   > File: 069_961_12.png | True: fake | Predicted: fake (96.34%)  [CORRECT]
#   > File: 067_025_3.png | True: fake | Predicted: fake (99.28%)  [CORRECT]
#   > File: 082_103_7.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 110_043_11.png | True: fake | Predicted: fake (54.14%)  [CORRECT]
#   > File: 109_107_11.png | True: fake | Predicted: fake (97.76%)  [CORRECT]
#   > File: 079_076_3.png | True: fake | Predicted: fake (96.11%)  [CORRECT]
#   > File: 081_087_34.png | True: fake | Predicted: fake (67.02%)  [CORRECT]
#   > File: 126_104_2.png | True: fake | Predicted: fake (75.70%)  [CORRECT]
#   > File: 077_100_23.png | True: fake | Predicted: fake (60.46%)  [CORRECT]
#   > File: 072_037_0.png | True: fake | Predicted: fake (51.19%)  [CORRECT]
#   > File: 113_983_23.png | True: fake | Predicted: fake (95.54%)  [CORRECT]
#   > File: 074_825_1.png | True: fake | Predicted: fake (56.00%)  [CORRECT]
#   > File: 070_057_13.png | True: fake | Predicted: fake (85.52%)  [CORRECT]
#   > File: 089_065_14.png | True: fake | Predicted: fake (75.19%)  [CORRECT]
#   > File: 088_060_19.png | True: fake | Predicted: real (52.29%)  [WRONG]
#   > File: 095_053_34.png | True: fake | Predicted: fake (71.89%)  [CORRECT]
#   > File: 106_198_9.png | True: fake | Predicted: fake (90.14%)  [CORRECT]
#   > File: 127_129_3.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 077_100_10.png | True: fake | Predicted: fake (73.58%)  [CORRECT]
#   > File: 118_120_4.png | True: fake | Predicted: real (53.59%)  [WRONG]
#   > File: 126_104_0.png | True: fake | Predicted: fake (56.17%)  [CORRECT]
#   > File: 080_061_5.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 113_983_9.png | True: fake | Predicted: fake (98.23%)  [CORRECT]
#   > File: 094_111_5.png | True: fake | Predicted: fake (82.28%)  [CORRECT]
#   > File: 103_082_15.png | True: fake | Predicted: fake (52.92%)  [CORRECT]
#   > File: 103_082_0.png | True: fake | Predicted: real (52.11%)  [WRONG]
#   > File: 075_977_6.png | True: fake | Predicted: fake (83.96%)  [CORRECT]
#   > File: 087_081_5.png | True: fake | Predicted: fake (61.82%)  [CORRECT]
#   > File: 106_198_10.png | True: fake | Predicted: fake (70.67%)  [CORRECT]
#   > File: 099_295_5.png | True: fake | Predicted: fake (88.01%)  [CORRECT]
#   > File: 089_065_17.png | True: fake | Predicted: fake (80.73%)  [CORRECT]
#   > File: 081_087_13.png | True: fake | Predicted: fake (64.14%)  [CORRECT]
#   > File: 088_060_8.png | True: fake | Predicted: fake (59.23%)  [CORRECT]
#   > File: 114_102_29.png | True: fake | Predicted: real (50.13%)  [WRONG]
#   > File: 114_102_27.png | True: fake | Predicted: fake (58.86%)  [CORRECT]
#   > File: 101_096_3.png | True: fake | Predicted: fake (99.70%)  [CORRECT]
#   > File: 088_060_9.png | True: fake | Predicted: real (52.35%)  [WRONG]
#   > File: 070_057_5.png | True: fake | Predicted: fake (94.91%)  [CORRECT]
#   > File: 084_042_3.png | True: fake | Predicted: fake (90.17%)  [CORRECT]
#   > File: 120_118_5.png | True: fake | Predicted: real (50.03%)  [WRONG]
#   > File: 098_092_5.png | True: fake | Predicted: fake (85.54%)  [CORRECT]
#   > File: 081_087_31.png | True: fake | Predicted: fake (65.71%)  [CORRECT]
#   > File: 127_129_18.png | True: fake | Predicted: real (52.39%)  [WRONG]
#   > File: 098_092_1.png | True: fake | Predicted: fake (66.30%)  [CORRECT]
#   > File: 079_076_11.png | True: fake | Predicted: fake (95.99%)  [CORRECT]
#   > File: 067_025_14.png | True: fake | Predicted: fake (98.43%)  [CORRECT]
#   > File: 113_983_16.png | True: fake | Predicted: fake (95.17%)  [CORRECT]
#   > File: 085_124_7.png | True: fake | Predicted: fake (61.09%)  [CORRECT]
#   > File: 072_037_2.png | True: fake | Predicted: fake (87.59%)  [CORRECT]
#   > File: 097_033_12.png | True: fake | Predicted: real (71.08%)  [WRONG]
#   > File: 091_116_6.png | True: fake | Predicted: fake (95.46%)  [CORRECT]
#   > File: 104_126_13.png | True: fake | Predicted: fake (64.34%)  [CORRECT]
#   > File: 091_116_13.png | True: fake | Predicted: fake (93.60%)  [CORRECT]
#   > File: 109_107_3.png | True: fake | Predicted: fake (91.03%)  [CORRECT]
#   > File: 092_098_10.png | True: fake | Predicted: real (52.32%)  [WRONG]
#   > File: 107_109_9.png | True: fake | Predicted: fake (66.55%)  [CORRECT]
#   > File: 124_085_0.png | True: fake | Predicted: fake (57.55%)  [CORRECT]
#   > File: 115_939_5.png | True: fake | Predicted: fake (63.98%)  [CORRECT]
#   > File: 073_024_21.png | True: fake | Predicted: fake (58.32%)  [CORRECT]
#   > File: 081_087_10.png | True: fake | Predicted: fake (74.44%)  [CORRECT]
#   > File: 090_086_10.png | True: fake | Predicted: fake (91.42%)  [CORRECT]
#   > File: 072_037_8.png | True: fake | Predicted: fake (94.23%)  [CORRECT]
#   > File: 124_085_10.png | True: fake | Predicted: fake (75.64%)  [CORRECT]
#   > File: 101_096_28.png | True: fake | Predicted: fake (99.05%)  [CORRECT]
#   > File: 083_213_10.png | True: fake | Predicted: fake (90.00%)  [CORRECT]
#   > File: 125_038_13.png | True: fake | Predicted: fake (65.02%)  [CORRECT]
#   > File: 100_077_9.png | True: fake | Predicted: fake (81.26%)  [CORRECT]
#   > File: 069_961_23.png | True: fake | Predicted: fake (86.24%)  [CORRECT]
#   > File: 089_065_0.png | True: fake | Predicted: fake (80.23%)  [CORRECT]
#   > File: 078_955_9.png | True: fake | Predicted: fake (66.68%)  [CORRECT]
#   > File: 089_065_15.png | True: fake | Predicted: fake (69.36%)  [CORRECT]
#   > File: 123_119_16.png | True: fake | Predicted: fake (51.23%)  [CORRECT]
#   > File: 073_024_22.png | True: fake | Predicted: fake (52.31%)  [CORRECT]
#   > File: 125_038_11.png | True: fake | Predicted: fake (52.61%)  [CORRECT]
#   > File: 117_217_4.png | True: fake | Predicted: fake (57.96%)  [CORRECT]
#   > File: 087_081_11.png | True: fake | Predicted: fake (67.08%)  [CORRECT]
#   > File: 109_107_5.png | True: fake | Predicted: fake (97.36%)  [CORRECT]
#   > File: 105_180_3.png | True: fake | Predicted: fake (69.40%)  [CORRECT]
#   > File: 114_102_40.png | True: fake | Predicted: real (52.35%)  [WRONG]
#   > File: 084_042_13.png | True: fake | Predicted: fake (93.05%)  [CORRECT]
#   > File: 108_052_3.png | True: fake | Predicted: fake (65.04%)  [CORRECT]
#   > File: 105_180_7.png | True: fake | Predicted: fake (61.26%)  [CORRECT]
#   > File: 102_114_7.png | True: fake | Predicted: fake (94.26%)  [CORRECT]
#   > File: 123_119_3.png | True: fake | Predicted: fake (52.56%)  [CORRECT]
#   > File: 084_042_18.png | True: fake | Predicted: fake (79.09%)  [CORRECT]
#   > File: 086_090_13.png | True: fake | Predicted: fake (68.46%)  [CORRECT]
#   > File: 086_090_24.png | True: fake | Predicted: fake (95.65%)  [CORRECT]
#   > File: 110_043_16.png | True: fake | Predicted: fake (75.64%)  [CORRECT]
#   > File: 089_065_21.png | True: fake | Predicted: fake (91.43%)  [CORRECT]
#   > File: 101_096_12.png | True: fake | Predicted: fake (96.19%)  [CORRECT]
#   > File: 097_033_8.png | True: fake | Predicted: real (62.11%)  [WRONG]
#   > File: 099_295_2.png | True: fake | Predicted: fake (56.57%)  [CORRECT]
#   > File: 108_052_9.png | True: fake | Predicted: fake (88.08%)  [CORRECT]
#   > File: 121_093_15.png | True: fake | Predicted: fake (61.57%)  [CORRECT]
#   > File: 091_116_18.png | True: fake | Predicted: fake (93.68%)  [CORRECT]
# ...
#   > File: 127_14.png | True: real | Predicted: real (62.82%)  [CORRECT]
#   > File: 069_1.png | True: real | Predicted: real (76.92%)  [CORRECT]
#   > File: 090_5.png | True: real | Predicted: real (77.21%)  [CORRECT]
#   > File: 093_11.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 081_21.png | True: real | Predicted: real (75.93%)  [CORRECT]
#   > File: 072_1.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 081_13.png | True: real | Predicted: real (59.31%)  [CORRECT]
#   > File: 107_7.png | True: real | Predicted: real (52.42%)  [CORRECT]
#   > File: 093_8.png | True: real | Predicted: real (51.02%)  [CORRECT]
#   > File: 068_3.png | True: real | Predicted: real (62.69%)  [CORRECT]
#   > File: 128_18.png | True: real | Predicted: real (50.14%)  [CORRECT]
#   > File: 095_14.png | True: real | Predicted: real (87.88%)  [CORRECT]
#   > File: 117_7.png | True: real | Predicted: real (60.11%)  [CORRECT]
#   > File: 086_22.png | True: real | Predicted: real (57.06%)  [CORRECT]
#   > File: 082_11.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 117_5.png | True: real | Predicted: real (53.99%)  [CORRECT]
#   > File: 105_6.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 116_7.png | True: real | Predicted: real (55.21%)  [CORRECT]
#   > File: 099_13.png | True: real | Predicted: real (83.84%)  [CORRECT]
#   > File: 123_3.png | True: real | Predicted: real (52.66%)  [CORRECT]
#   > File: 097_3.png | True: real | Predicted: real (56.10%)  [CORRECT]
#   > File: 127_22.png | True: real | Predicted: real (61.90%)  [CORRECT]
#   > File: 070_5.png | True: real | Predicted: real (73.61%)  [CORRECT]
#   > File: 082_1.png | True: real | Predicted: real (76.81%)  [CORRECT]
#   > File: 120_10.png | True: real | Predicted: real (93.79%)  [CORRECT]
#   > File: 119_11.png | True: real | Predicted: real (52.76%)  [CORRECT]
#   > File: 114_0.png | True: real | Predicted: real (86.84%)  [CORRECT]
#   > File: 068_11.png | True: real | Predicted: real (53.17%)  [CORRECT]
#   > File: 106_1.png | True: real | Predicted: real (60.23%)  [CORRECT]
#   > File: 112_0.png | True: real | Predicted: real (79.83%)  [CORRECT]
#   > File: 073_2.png | True: real | Predicted: real (89.06%)  [CORRECT]
#   > File: 081_20.png | True: real | Predicted: real (52.44%)  [CORRECT]
#   > File: 073_14.png | True: real | Predicted: real (71.71%)  [CORRECT]
#   > File: 124_1.png | True: real | Predicted: fake (57.28%)  [WRONG]
#   > File: 079_6.png | True: real | Predicted: real (75.20%)  [CORRECT]
#   > File: 118_12.png | True: real | Predicted: real (57.39%)  [CORRECT]
#   > File: 126_10.png | True: real | Predicted: real (65.63%)  [CORRECT]
#   > File: 085_11.png | True: real | Predicted: real (99.35%)  [CORRECT]
#   > File: 086_6.png | True: real | Predicted: real (55.14%)  [CORRECT]
#   > File: 103_10.png | True: real | Predicted: real (53.22%)  [CORRECT]
#   > File: 107_13.png | True: real | Predicted: real (52.57%)  [CORRECT]
#   > File: 103_5.png | True: real | Predicted: real (88.69%)  [CORRECT]
#   > File: 103_14.png | True: real | Predicted: real (71.35%)  [CORRECT]
#   > File: 111_10.png | True: real | Predicted: real (56.80%)  [CORRECT]
#   > File: 121_1.png | True: real | Predicted: real (83.15%)  [CORRECT]
#   > File: 081_6.png | True: real | Predicted: real (63.40%)  [CORRECT]
#   > File: 101_28.png | True: real | Predicted: real (77.05%)  [CORRECT]
#   > File: 114_45.png | True: real | Predicted: real (67.03%)  [CORRECT]
#   > File: 070_1.png | True: real | Predicted: real (52.30%)  [CORRECT]
#   > File: 113_32.png | True: real | Predicted: real (90.73%)  [CORRECT]
#   > File: 117_4.png | True: real | Predicted: real (65.54%)  [CORRECT]
#   > File: 107_8.png | True: real | Predicted: real (72.27%)  [CORRECT]
#   > File: 082_7.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 092_11.png | True: real | Predicted: real (53.82%)  [CORRECT]
#   > File: 075_10.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 123_2.png | True: real | Predicted: real (56.71%)  [CORRECT]
#   > File: 116_2.png | True: real | Predicted: fake (68.76%)  [WRONG]
#   > File: 101_23.png | True: real | Predicted: real (89.40%)  [CORRECT]
#   > File: 088_7.png | True: real | Predicted: real (90.39%)  [CORRECT]
#   > File: 118_5.png | True: real | Predicted: real (63.87%)  [CORRECT]
#   > File: 088_20.png | True: real | Predicted: real (79.42%)  [CORRECT]
#   > File: 082_3.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 084_13.png | True: real | Predicted: real (64.73%)  [CORRECT]
#   > File: 128_16.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 114_30.png | True: real | Predicted: fake (62.68%)  [WRONG]
#   > File: 102_10.png | True: real | Predicted: real (78.80%)  [CORRECT]
#   > File: 073_24.png | True: real | Predicted: real (87.73%)  [CORRECT]
#   > File: 094_3.png | True: real | Predicted: fake (60.65%)  [WRONG]
#   > File: 110_10.png | True: real | Predicted: real (59.50%)  [CORRECT]
#   > File: 101_13.png | True: real | Predicted: real (60.10%)  [CORRECT]
#   > File: 128_14.png | True: real | Predicted: real (83.15%)  [CORRECT]
#   > File: 121_15.png | True: real | Predicted: real (62.04%)  [CORRECT]
#   > File: 081_29.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 072_6.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 086_8.png | True: real | Predicted: real (55.20%)  [CORRECT]
#   > File: 079_3.png | True: real | Predicted: real (93.14%)  [CORRECT]
#   > File: 086_0.png | True: real | Predicted: real (91.27%)  [CORRECT]
#   > File: 085_10.png | True: real | Predicted: real (89.95%)  [CORRECT]
#   > File: 075_19.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 116_9.png | True: real | Predicted: real (51.93%)  [CORRECT]
#   > File: 114_25.png | True: real | Predicted: real (52.37%)  [CORRECT]
#   > File: 105_9.png | True: real | Predicted: real (80.72%)  [CORRECT]
#   > File: 110_8.png | True: real | Predicted: real (58.12%)  [CORRECT]
#   > File: 087_6.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 077_9.png | True: real | Predicted: real (88.62%)  [CORRECT]
#   > File: 123_7.png | True: real | Predicted: real (53.55%)  [CORRECT]
#   > File: 071_1.png | True: real | Predicted: real (53.22%)  [CORRECT]
#   > File: 096_14.png | True: real | Predicted: real (56.87%)  [CORRECT]
#   > File: 120_6.png | True: real | Predicted: real (88.61%)  [CORRECT]
#   > File: 113_24.png | True: real | Predicted: real (66.23%)  [CORRECT]
#   > File: 083_10.png | True: real | Predicted: real (69.81%)  [CORRECT]
#   > File: 129_0.png | True: real | Predicted: real (57.74%)  [CORRECT]
#   > File: 108_0.png | True: real | Predicted: real (85.66%)  [CORRECT]
#   > File: 096_15.png | True: real | Predicted: real (58.65%)  [CORRECT]
#   > File: 112_6.png | True: real | Predicted: real (64.65%)  [CORRECT]
#   > File: 125_12.png | True: real | Predicted: real (55.51%)  [CORRECT]
#   > File: 089_24.png | True: real | Predicted: real (54.16%)  [CORRECT]
#   > File: 121_6.png | True: real | Predicted: real (61.28%)  [CORRECT]
#   > File: 128_8.png | True: real | Predicted: real (57.09%)  [CORRECT]
#   > File: 081_12.png | True: real | Predicted: real (52.91%)  [CORRECT]
#   > File: 089_25.png | True: real | Predicted: real (55.10%)  [CORRECT]
#   > File: 101_27.png | True: real | Predicted: real (62.14%)  [CORRECT]
#   > File: 119_10.png | True: real | Predicted: real (54.98%)  [CORRECT]
#   > File: 098_6.png | True: real | Predicted: real (70.21%)  [CORRECT]
#   > File: 070_6.png | True: real | Predicted: real (53.71%)  [CORRECT]
#   > File: 108_3.png | True: real | Predicted: real (64.94%)  [CORRECT]
#   > File: 119_2.png | True: real | Predicted: real (58.71%)  [CORRECT]
#   > File: 103_21.png | True: real | Predicted: real (58.01%)  [CORRECT]
#   > File: 120_3.png | True: real | Predicted: real (79.49%)  [CORRECT]
#   > File: 080_14.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 114_20.png | True: real | Predicted: real (65.54%)  [CORRECT]
#   > File: 119_5.png | True: real | Predicted: real (52.12%)  [CORRECT]
#   > File: 110_18.png | True: real | Predicted: real (52.36%)  [CORRECT]
#   > File: 089_5.png | True: real | Predicted: real (55.46%)  [CORRECT]
#   > File: 081_22.png | True: real | Predicted: real (79.75%)  [CORRECT]
#   > File: 074_1.png | True: real | Predicted: real (81.91%)  [CORRECT]
#   > File: 102_0.png | True: real | Predicted: real (65.84%)  [CORRECT]
#   > File: 114_32.png | True: real | Predicted: real (62.73%)  [CORRECT]
#   > File: 126_4.png | True: real | Predicted: real (83.70%)  [CORRECT]
#   > File: 113_2.png | True: real | Predicted: real (93.67%)  [CORRECT]
#   > File: 079_11.png | True: real | Predicted: real (90.61%)  [CORRECT]
#   > File: 070_0.png | True: real | Predicted: real (70.25%)  [CORRECT]
#   > File: 082_6.png | True: real | Predicted: real (69.62%)  [CORRECT]
#   > File: 099_16.png | True: real | Predicted: real (74.29%)  [CORRECT]
#   > File: 121_9.png | True: real | Predicted: real (65.46%)  [CORRECT]
#   > File: 075_8.png | True: real | Predicted: real (56.59%)  [CORRECT]
#   > File: 069_22.png | True: real | Predicted: real (74.88%)  [CORRECT]
#   > File: 103_13.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 092_6.png | True: real | Predicted: real (62.57%)  [CORRECT]
#   > File: 113_27.png | True: real | Predicted: real (75.02%)  [CORRECT]
#   > File: 124_10.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 068_10.png | True: real | Predicted: real (57.63%)  [CORRECT]
#   > File: 118_1.png | True: real | Predicted: real (73.58%)  [CORRECT]
#   > File: 095_4.png | True: real | Predicted: real (67.37%)  [CORRECT]
#   > File: 082_12.png | True: real | Predicted: real (74.23%)  [CORRECT]
#   > File: 084_9.png | True: real | Predicted: real (59.31%)  [CORRECT]
#   > File: 071_9.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 127_19.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 073_10.png | True: real | Predicted: real (63.10%)  [CORRECT]
#   > File: 122_4.png | True: real | Predicted: real (83.22%)  [CORRECT]
#   > File: 095_25.png | True: real | Predicted: real (51.58%)  [CORRECT]
#   > File: 123_0.png | True: real | Predicted: real (78.75%)  [CORRECT]
#   > File: 094_18.png | True: real | Predicted: fake (53.93%)  [WRONG]
#   > File: 121_11.png | True: real | Predicted: real (77.20%)  [CORRECT]
#   > File: 088_16.png | True: real | Predicted: real (87.54%)  [CORRECT]
#   > File: 081_35.png | True: real | Predicted: real (64.00%)  [CORRECT]
#   > File: 101_0.png | True: real | Predicted: real (92.55%)  [CORRECT]
#   > File: 085_1.png | True: real | Predicted: real (92.22%)  [CORRECT]
#   > File: 103_15.png | True: real | Predicted: real (53.24%)  [CORRECT]
#   > File: 114_8.png | True: real | Predicted: real (73.84%)  [CORRECT]
#   > File: 114_13.png | True: real | Predicted: real (69.57%)  [CORRECT]
#   > File: 072_0.png | True: real | Predicted: fake (64.97%)  [WRONG]
#   > File: 117_13.png | True: real | Predicted: real (58.74%)  [CORRECT]
#   > File: 109_1.png | True: real | Predicted: real (78.03%)  [CORRECT]
#   > File: 114_39.png | True: real | Predicted: real (56.03%)  [CORRECT]
#   > File: 124_4.png | True: real | Predicted: fake (55.29%)  [WRONG]
#   > File: 112_10.png | True: real | Predicted: real (66.90%)  [CORRECT]
#   > File: 084_8.png | True: real | Predicted: real (53.81%)  [CORRECT]
#   > File: 110_5.png | True: real | Predicted: real (52.87%)  [CORRECT]
#   > File: 116_8.png | True: real | Predicted: real (52.10%)  [CORRECT]
#   > File: 081_17.png | True: real | Predicted: real (82.83%)  [CORRECT]
#   > File: 102_8.png | True: real | Predicted: real (81.74%)  [CORRECT]
#   > File: 084_2.png | True: real | Predicted: real (60.81%)  [CORRECT]
#   > File: 092_12.png | True: real | Predicted: real (64.69%)  [CORRECT]
#   > File: 069_4.png | True: real | Predicted: real (61.73%)  [CORRECT]
#   > File: 072_10.png | True: real | Predicted: fake (63.60%)  [WRONG]
#   > File: 125_1.png | True: real | Predicted: real (59.44%)  [CORRECT]
#   > File: 076_9.png | True: real | Predicted: real (97.15%)  [CORRECT]
#   > File: 086_13.png | True: real | Predicted: real (58.72%)  [CORRECT]
#   > File: 099_22.png | True: real | Predicted: real (98.26%)  [CORRECT]
#   > File: 093_12.png | True: real | Predicted: real (52.41%)  [CORRECT]
#   > File: 128_24.png | True: real | Predicted: real (80.68%)  [CORRECT]
#   > File: 075_0.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 101_37.png | True: real | Predicted: real (74.70%)  [CORRECT]
#   > File: 082_8.png | True: real | Predicted: real (78.36%)  [CORRECT]
#   > File: 084_12.png | True: real | Predicted: real (50.03%)  [CORRECT]
#   > File: 078_14.png | True: real | Predicted: real (93.72%)  [CORRECT]
#   > File: 091_10.png | True: real | Predicted: real (90.50%)  [CORRECT]
#   > File: 081_25.png | True: real | Predicted: real (86.34%)  [CORRECT]
#   > File: 114_42.png | True: real | Predicted: real (87.62%)  [CORRECT]
#   > File: 072_2.png | True: real | Predicted: real (57.91%)  [CORRECT]
#   > File: 089_4.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 114_37.png | True: real | Predicted: real (55.24%)  [CORRECT]
#   > File: 088_13.png | True: real | Predicted: real (75.17%)  [CORRECT]
#   > File: 069_23.png | True: real | Predicted: real (89.07%)  [CORRECT]
#   > File: 095_23.png | True: real | Predicted: real (84.43%)  [CORRECT]
#   > File: 068_5.png | True: real | Predicted: real (82.10%)  [CORRECT]
#   > File: 095_34.png | True: real | Predicted: real (51.25%)  [CORRECT]
#   > File: 101_14.png | True: real | Predicted: real (66.71%)  [CORRECT]
#   > File: 101_36.png | True: real | Predicted: real (59.02%)  [CORRECT]
#   > File: 101_6.png | True: real | Predicted: real (69.73%)  [CORRECT]
#   > File: 081_11.png | True: real | Predicted: real (75.04%)  [CORRECT]
#   > File: 105_5.png | True: real | Predicted: real (52.87%)  [CORRECT]
#   > File: 097_7.png | True: real | Predicted: real (52.57%)  [CORRECT]
#   > File: 100_10.png | True: real | Predicted: real (67.08%)  [CORRECT]
#   > File: 111_13.png | True: real | Predicted: real (52.15%)  [CORRECT]
#   > File: 113_19.png | True: real | Predicted: real (53.06%)  [CORRECT]
#   > File: 114_23.png | True: real | Predicted: real (76.16%)  [CORRECT]
#   > File: 110_7.png | True: real | Predicted: real (65.16%)  [CORRECT]
#   > File: 101_30.png | True: real | Predicted: real (73.35%)  [CORRECT]
#   > File: 077_13.png | True: real | Predicted: real (87.15%)  [CORRECT]
#   > File: 094_21.png | True: real | Predicted: fake (59.59%)  [WRONG]
#   > File: 096_5.png | True: real | Predicted: real (57.06%)  [CORRECT]
#   > File: 113_16.png | True: real | Predicted: real (96.41%)  [CORRECT]
#   > File: 087_4.png | True: real | Predicted: real (52.39%)  [CORRECT]
#   > File: 110_9.png | True: real | Predicted: real (52.46%)  [CORRECT]
#   > File: 095_10.png | True: real | Predicted: real (61.77%)  [CORRECT]
#   > File: 077_5.png | True: real | Predicted: real (92.41%)  [CORRECT]
#   > File: 113_9.png | True: real | Predicted: real (95.59%)  [CORRECT]
#   > File: 119_16.png | True: real | Predicted: real (76.36%)  [CORRECT]
#   > File: 106_4.png | True: real | Predicted: real (52.38%)  [CORRECT]
#   > File: 074_9.png | True: real | Predicted: real (65.32%)  [CORRECT]
#   > File: 074_11.png | True: real | Predicted: real (93.19%)  [CORRECT]
#   > File: 094_22.png | True: real | Predicted: fake (76.64%)  [WRONG]
#   > File: 077_22.png | True: real | Predicted: real (71.68%)  [CORRECT]
#   > File: 081_18.png | True: real | Predicted: real (92.31%)  [CORRECT]
#   > File: 107_6.png | True: real | Predicted: real (52.43%)  [CORRECT]
#   > File: 099_18.png | True: real | Predicted: real (63.99%)  [CORRECT]
#   > File: 103_3.png | True: real | Predicted: real (58.02%)  [CORRECT]
#   > File: 113_1.png | True: real | Predicted: real (66.48%)  [CORRECT]
#   > File: 111_2.png | True: real | Predicted: real (56.37%)  [CORRECT]
#   > File: 097_17.png | True: real | Predicted: real (52.39%)  [CORRECT]
#
# --- Evaluation Summary ---
# Total Images: 2400
# Correct Predictions: 2201
# OVERALL ACCURACY: 91.71%
# --------------------------
