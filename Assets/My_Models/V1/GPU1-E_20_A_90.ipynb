# %% [markdown]
# ### Cell 1: Check Data Directories
# This step remains the same.

# %%
# !ls /kaggle/input/1000-videos-split/1000_videos/train/fake | head -n 5
# !ls /kaggle/input/1000-videos-split/1000_videos/train/real | head -n 5
# Out:
# 128_896_10.png
# 128_896_11.png
# 128_896_12.png
# 128_896_13.png
# 128_896_14.png
# ls: write error: Broken pipe
# 129_10.png
# 129_2.png
# 129_3.png
# 129_4.png
# 129_5.png
# ls: write error: Broken pipe

# %% [markdown]
# ### Hardware Detection
#
# This cell runs a check to identify the available hardware and selects the appropriate TensorFlow distribution strategy.

# %%
import tensorflow as tf
import os

def get_distribution_strategy():
    """
    Detects available hardware (TPU, multi-GPU, single-GPU, CPU) and returns
    the appropriate TensorFlow distribution strategy.
    """
    try:
        # Attempt to detect and initialize a TPU
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        strategy = tf.distribute.TPUStrategy(tpu)
        print("✅ Running on TPU")
    except (ValueError, tf.errors.NotFoundError):
        # If no TPU is found, check for GPUs
        gpus = tf.config.list_physical_devices('GPU')
        if len(gpus) > 1:
            # If multiple GPUs are available, use MirroredStrategy
            strategy = tf.distribute.MirroredStrategy()
            print(f"✅ Running on {len(gpus)} GPUs")
        elif len(gpus) == 1:
            # If a single GPU is available, use the default strategy
            strategy = tf.distribute.get_strategy()
            print("✅ Running on a single GPU")
        else:
            # If no GPUs are found, run on CPU
            strategy = tf.distribute.get_strategy()
            print("✅ Running on CPU")
            
    print(f"Number of accelerator replicas: {strategy.num_replicas_in_sync}")
    return strategy

# Run the detection function to see what hardware is available
strategy = get_distribution_strategy()
# Out:
# ✅ Running on a single GPU
# Number of accelerator replicas: 1

# %% [markdown]
# ### Cell 3: Introduction
# This cell provides an overview of the notebook's purpose and structure.
#
# # Deepfake Detection with Soft Attention
#
# This notebook sets up and runs the Deepfake Video Forgery Detection project using the original provided Python scripts. The process is broken down into clear, documented stages:
#
# 1.  **Setup and Writing Project Files:** Each of the original Python scripts (`model.py`, `utils.py`, `train.py`, `main.py`) will be written to the Kaggle environment. Critical, minimal fixes are applied to ensure the project can run and save the final model.
# 2.  **Training the Model:** The main training script is executed using a command line call, just as designed in the original project.
# 3.  **Prediction:** A final script is provided to easily test the trained model on new images.

# %% [markdown]
# ### Writing `model.py`
#
# This script defines the neural network architecture. The following critical modifications were necessary:
#
# -   **Corrected Layer Instantiation:** Layers are now correctly defined once in the `build()` method and used in the `call()` method. This is essential to allow the model to be saved.
# -   **Added `**kwargs`:** The `__init__` methods of the custom layers have been updated to accept extra arguments from Keras during model loading.

# %%
# %%writefile model.py
import tensorflow as tf

def backbone():
    '''
    RETURNS THE BACKBONE FEATURE ENCODER NETWORK
    XCEPTION USED IN THIS CASE
    '''
    mod  = tf.keras.applications.Xception(weights='imagenet')
    mod = tf.keras.Model(mod.input, mod.layers[-13].output)
    return mod
    
class ModifiedBranch(tf.keras.layers.Layer):
    '''
    COMPUTES THE MODIFIED BRANCH TO BE USED IN ATTENTION TECHNIQUE
    '''
    def __init__(self, a_vec_size, **kwargs):
        super(ModifiedBranch, self).__init__(**kwargs)
        self.a_vec_size = a_vec_size

    def build(self, input_shape):
        self.dense_layer = tf.keras.layers.Dense(self.a_vec_size, activation='tanh')

    def call(self, input):
        af = tf.keras.backend.mean(input, axis=2) 
        hs = self.dense_layer(af)
        return hs

class MainBranch(tf.keras.layers.Layer):
    def __init__(self, a_vec_size, dim, **kwargs):
        super(MainBranch, self).__init__(**kwargs)
        self.a_vec_size = a_vec_size
        self.dim = dim

    def build(self, input_shape):
        self.reshape1 = tf.keras.layers.Reshape((-1, self.a_vec_size))
        self.relu = tf.keras.activations.relu
        self.dropout = tf.keras.layers.Dropout(0.5)
        self.reshape2 = tf.keras.layers.Reshape((self.dim**2, self.a_vec_size))

    def call(self, input):
        e = tf.transpose(input, perm=[0, 2, 1])
        e = self.reshape1(e)
        e = self.relu(e)
        e = self.dropout(e)
        e = self.reshape2(e)
        e = tf.transpose(e, perm=[0, 2, 1])
        return e

class Attention(tf.keras.layers.Layer):
    '''
    IMPLEMENTATION OF THE ATTENTION TECHNIQUE ON TWO BRANCHES
    '''
    def __init__(self, dim, a_vec_size, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dim = dim
        self.a_vec_size = a_vec_size
    
    def build(self, input_shape):
        self.dense1 = tf.keras.layers.Dense(self.dim**2)
        self.reshape1 = tf.keras.layers.Reshape((1, self.dim**2))
        self.add = tf.keras.layers.Add()
        self.dropout = tf.keras.layers.Dropout(0.5)
        self.relu = tf.keras.activations.relu
        self.reshape2 = tf.keras.layers.Reshape((-1, self.a_vec_size))
        self.dense2 = tf.keras.layers.Dense(1, use_bias=False)
        self.reshape3 = tf.keras.layers.Reshape((-1, self.dim**2))

    def call(self, input):
        eh = self.dense1(input[0])
        eh = self.reshape1(eh)
        eh = self.add([input[1], eh])
        eh = self.relu(eh)
        eh = self.dropout(eh)
        eh = tf.transpose(eh, perm=[0, 2, 1])
        eh = self.reshape2(eh)
        eh = self.dense2(eh)
        eh = self.reshape3(eh)
        eh = self.relu(eh)
        return eh

def model(a_vec_size, dim):
    '''
    THIS FUNCTION CALLS THE ENTIRE MODEL
    '''
    back = backbone()
    backbone_feature = back.output  
    out = tf.keras.layers.Conv2D(filters = a_vec_size, kernel_size = (1,1), strides=(1,1), padding = 'valid', use_bias=True)(backbone_feature)
    out = tf.keras.layers.BatchNormalization(axis=-1)(out)
    out = tf.keras.activations.relu(out)
    out = tf.keras.layers.Dropout(0.8)(out)
    out = tf.keras.layers.Reshape((a_vec_size, dim**2))(out)
    
    modified = ModifiedBranch(a_vec_size)(out)
    main = MainBranch(a_vec_size, dim)(out)
    att = Attention(dim, a_vec_size)([modified, main])
    fin = tf.keras.layers.Dense(2, activation='softmax')(att)
    fin = tf.keras.layers.Flatten()(fin)
    mod = tf.keras.Model(inputs=back.input, outputs=fin)
    return mod
# Out:
# Overwriting model.py

# %% [markdown]
# ### Writing `utils.py`
#
# This script handles data loading. The following modifications were essential:
#
# -   **Corrected Label Reading:** The `get_output` function was changed to read the label from the parent directory name (e.g., `.../fake/` or `.../real/`).
# -   **Added Preprocessing:** The `image_generator` now correctly applies `preprocess_input` for the Xception model, which is critical for transfer learning.

# %%
# %%writefile utils.py
import os
import cv2
import glob
import numpy as np
from tensorflow.keras.applications.xception import preprocess_input

def get_input(path):
    im = cv2.imread(path)
    return(im)

def get_files(path, ext):
    files = []
    label_files= []
    for x in os.walk(path):
        for y in glob.glob(os.path.join(x[0], '*.{}'.format(ext))):
            files.append(y)
    label_files = ['fake', 'real']
    return files, label_files

def get_output(path, label_file):
    img_id = path.split('/')[-2] 
    laba = []
    for label in label_file:
      if label == img_id:
        laba.append(1)
      else:
        laba.append(0)
    return laba

def image_generator(files, label_files, batch_size, resize=None):
    while True:
          batch_paths  = np.random.choice(a  = files, 
                                          size = batch_size)
          batch_x = []
          batch_y = [] 
          
          for input_path in batch_paths:
              input_img = get_input(input_path)
              output = get_output(input_path, label_files)
              
              if resize is not None:
                input_img = cv2.resize(input_img, resize)
              
              input_img = preprocess_input(input_img) 
              
              batch_x.append(input_img)
              batch_y.append(output)

          batch_x = np.array(batch_x)
          batch_y = np.array(batch_y)
          yield batch_x, batch_y
# Out:
# Overwriting utils.py

# %% [markdown]
# ### Writing `train.py` (Modified for Universal Compatibility)
#
# This script is the main training engine. It has been significantly modified to support all hardware types:
#
# -   **Universal Hardware Detection:** It includes a function that detects TPUs, multiple GPUs, a single GPU, or defaults to CPU.
# -   **Strategy Scope:** The model creation and compilation steps are now correctly placed inside the appropriate `strategy.scope()`, which is a requirement for all forms of distributed training (TPU and multi-GPU).
# -   **Enabled Model Checkpointing:** The `ModelCheckpoint` callback is enabled to save the best version of the model.

# %%
# %%writefile train.py
import os
import utils
import model
import tensorflow as tf

def get_distribution_strategy():
    """
    Detects available hardware (TPU, multi-GPU, single-GPU, CPU) and returns
    the appropriate TensorFlow distribution strategy.
    """
    try:
        # Attempt to detect and initialize a TPU
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        strategy = tf.distribute.TPUStrategy(tpu)
        print("✅ Running on TPU")
    except (ValueError, tf.errors.NotFoundError):
        # If no TPU is found, check for GPUs
        gpus = tf.config.list_physical_devices('GPU')
        if len(gpus) > 1:
            # If multiple GPUs are available, use MirroredStrategy
            strategy = tf.distribute.MirroredStrategy()
            print(f"✅ Running on {len(gpus)} GPUs")
        elif len(gpus) == 1:
            # If a single GPU is available, use the default strategy
            strategy = tf.distribute.get_strategy()
            print("✅ Running on a single GPU")
        else:
            # If no GPUs are found, run on CPU
            strategy = tf.distribute.get_strategy()
            print("✅ Running on CPU")
            
    print(f"Number of accelerator replicas: {strategy.num_replicas_in_sync}")
    return strategy

class train():
    def __init__(self, train_path, val_path):
        self.train_path = train_path
        self.val_path = val_path
        here = os.path.dirname(os.path.abspath(__file__))
        self.path = os.path.join(here, "models")
        os.makedirs(self.path, exist_ok=True)
    
    def get_files(self):
        self.train_files, self.label_files = utils.get_files(self.train_path, 'png')
        self.val_files, self.label_files = utils.get_files(self.val_path, 'png')

    def run(self, epochs, batch_size, steps, dim=(299, 299)):
        self.get_files()
        
        # MODIFICATION: Get the appropriate strategy for the available hardware
        strategy = get_distribution_strategy()

        # MODIFICATION: The model must be created and compiled inside the strategy's scope.
        with strategy.scope():
            mod = model.model(1024, 19)
            mod.compile('Adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])

        print("************TRAINING SOFT ATTENTION BASED DEEP FAKE DETECTION MODEL************")
        
        checkpoint_filepath = os.path.join(self.path, "best_model.keras")
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath, 
            save_best_only=True, 
            monitor='val_accuracy', 
            mode='max'
        )

        mod.fit(utils.image_generator(self.train_files, self.label_files, batch_size, dim), 
                  epochs=epochs, 
                  steps_per_epoch=steps,
                  validation_data=utils.image_generator(self.val_files, self.label_files, batch_size, dim),
                  validation_steps=50,
                  callbacks=[model_checkpoint_callback])
# Out:
# Overwriting train.py

# %% [markdown]
# ### Writing `main.py`
#
# This script parses command-line arguments and starts the training. No modifications were needed.

# %%
# %%writefile main.py
import argparse
from train import train

def main():
    parser = argparse.ArgumentParser(description='Visual Attention based Deepfake Video Forgery Detection')

    parser.add_argument('--train', type=str, nargs = '+', help = 'What is the path of the training image data?')
    parser.add_argument('--val', type=str, nargs = '+', help = 'What is the path of the Validation image data?')
    parser.add_argument('--epochs', type=int, default=50, help = 'What is the training epoch for model?')
    parser.add_argument('--batch', type=int, default=32, help = 'What is the training batch size?')
    parser.add_argument('--steps', type=int, default=40, help = 'What is the training steps per epoch?')

    args = parser.parse_args()
    args.train = ' '.join(args.train)
    args.val = ' '.join(args.val)

    print("Configuration")
    print("----------------------------------------------------------------------")
    print("Training Path : {}".format(args.train))
    print("Validation Path : {}".format(args.val))
    print("Epochs while training the model : {}".format(args.epochs))
    print("Batch Size : {}".format(args.batch))
    print("Steps per epochs : {}".format(args.steps))
    print("----------------------------------------------------------------------")

    train(args.train, args.val).run(args.epochs, args.batch, args.steps)

if __name__=='__main__':
    main()
# Out:
# Overwriting main.py

# %% [markdown]
# ## Stage 2: Training the Model
#
# Now that all scripts are written and corrected, we can run the training process.
#
# **Important:** You must update the `--train` and `--val` paths below to point to your dataset's location in the Kaggle input directory (e.g., `/kaggle/input/your-dataset-name/...`). You should also calculate and set the `--steps` argument properly.
#
# **How to calculate `--steps`:**
# `steps = (total_number_of_training_images) / batch_size`

# %%
# Example Usage: total file no /batch = steps

# !python main.py \
    --train "/kaggle/input/1000-videos-split/1000_videos/train" \
    --val "/kaggle/input/1000-videos-split/1000_videos/validation" \
    --epochs 60 \
    --batch 16 \
    --steps 727
# Out:
# 2025-09-21 13:22:11.857510: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758460931.878537   29099 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758460931.884839   29099 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Configuration
# ----------------------------------------------------------------------
# Training Path : /kaggle/input/1000-videos-split/1000_videos/train
# Validation Path : /kaggle/input/1000-videos-split/1000_videos/validation
# Epochs while training the model : 60
# Batch Size : 16
# Steps per epochs : 727
# ----------------------------------------------------------------------
# ✅ Running on a single GPU
# Number of accelerator replicas: 1
# I0000 00:00:1758460948.449010   29099 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# ************TRAINING SOFT ATTENTION BASED DEEP FAKE DETECTION MODEL************
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758460979.643120   29120 service.cc:148] XLA service 0x7f53a00027c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758460979.643161   29120 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1758460982.458984   29120 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1758460992.467653   29120 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1758460992.677376   29120 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1758460993.744356   29120 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1758460993.975969   29120 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1758460994.896065   29120 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1758460995.085056   29120 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1758461004.136684   29120 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 230s 242ms/step - accuracy: 0.6300 - loss: 0.7823 - val_accuracy: 0.8475 - val_loss: 0.5769
# Epoch 2/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 175s 241ms/step - accuracy: 0.9363 - loss: 0.1739 - val_accuracy: 0.8800 - val_loss: 0.3713
# Epoch 3/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 234ms/step - accuracy: 0.9529 - loss: 0.1175 - val_accuracy: 0.8438 - val_loss: 0.5581
# Epoch 4/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 171s 236ms/step - accuracy: 0.9517 - loss: 0.1209 - val_accuracy: 0.9112 - val_loss: 0.3185
# Epoch 5/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 233ms/step - accuracy: 0.9685 - loss: 0.0893 - val_accuracy: 0.8425 - val_loss: 0.5164
# Epoch 6/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 169s 233ms/step - accuracy: 0.9650 - loss: 0.0963 - val_accuracy: 0.8250 - val_loss: 0.4692
# Epoch 7/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 233ms/step - accuracy: 0.9707 - loss: 0.0797 - val_accuracy: 0.8888 - val_loss: 0.2892
# Epoch 8/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 169s 233ms/step - accuracy: 0.9693 - loss: 0.0756 - val_accuracy: 0.7000 - val_loss: 0.5795
# Epoch 9/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 171s 235ms/step - accuracy: 0.9705 - loss: 0.0789 - val_accuracy: 0.9200 - val_loss: 0.4655
# Epoch 10/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 169s 233ms/step - accuracy: 0.9778 - loss: 0.0618 - val_accuracy: 0.8662 - val_loss: 0.4442
# Epoch 11/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 169s 233ms/step - accuracy: 0.9786 - loss: 0.0547 - val_accuracy: 0.6938 - val_loss: 0.4841
# Epoch 12/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 171s 235ms/step - accuracy: 0.9804 - loss: 0.0498 - val_accuracy: 0.9287 - val_loss: 0.5024
# Epoch 13/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 171s 235ms/step - accuracy: 0.9794 - loss: 0.0523 - val_accuracy: 0.9538 - val_loss: 0.1953
# Epoch 14/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 169s 233ms/step - accuracy: 0.9802 - loss: 0.0479 - val_accuracy: 0.8700 - val_loss: 0.3136
# Epoch 15/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 169s 233ms/step - accuracy: 0.9798 - loss: 0.0496 - val_accuracy: 0.7788 - val_loss: 0.6112
# Epoch 16/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 233ms/step - accuracy: 0.9830 - loss: 0.0373 - val_accuracy: 0.5362 - val_loss: 0.6881
# Epoch 17/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 233ms/step - accuracy: 0.9723 - loss: 0.0732 - val_accuracy: 0.9488 - val_loss: 0.2883
# Epoch 18/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 233ms/step - accuracy: 0.9805 - loss: 0.0401 - val_accuracy: 0.6500 - val_loss: 0.5404
# Epoch 19/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 170s 234ms/step - accuracy: 0.9852 - loss: 0.0331 - val_accuracy: 0.6313 - val_loss: 0.6355
# Epoch 20/60
# 727/727 ━━━━━━━━━━━━━━━━━━━━ 171s 235ms/step - accuracy: 0.9822 - loss: 0.0451 - val_accuracy: 0.5000 - val_loss: 0.5862
# Epoch 21/60
# 266/727 ━━━━━━━━━━━━━━━━━━━━ 1:45 230ms/step - accuracy: 0.9798 - loss: 0.0417^C
# Traceback (most recent call last):
#   File "/kaggle/working/main.py", line 29, in <module>
#     main()
#   File "/kaggle/working/main.py", line 26, in main
#     train(args.train, args.val).run(args.epochs, args.batch, args.steps)
#   File "/kaggle/working/train.py", line 68, in run
#     mod.fit(utils.image_generator(self.train_files, self.label_files, batch_size, dim),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#     logs = self.train_function(iterator)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 220, in function
#     if not opt_outputs.has_value():
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/data/ops/optional_ops.py", line 176, in has_value
#     return gen_optional_ops.optional_has_value(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_optional_ops.py", line 172, in optional_has_value
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !zip -r my_model.zip models/
# Out:
# updating: models/ (stored 0%)
# updating: models/best_model.keras (deflated 8%)

# %% [markdown]
# ## Stage 3: Prediction
#
# After training, a file named `best_model.keras` will be saved in the `/kaggle/working/models/` directory. We can use this model to make predictions on new, unseen images.
#
# First, we'll write a `predict.py` script to handle loading the model and processing an image.

# %%
# %%writefile predict.py
import tensorflow as tf
import numpy as np
import cv2
import argparse
import os

# --- Import your custom layers and preprocessing function ---
from model import ModifiedBranch, MainBranch, Attention
from tensorflow.keras.applications.xception import preprocess_input

# Define the labels list globally
LABELS = ['fake', 'real']

def load_and_prep_image(image_path, target_size=(299, 299)):
    """
    Loads, resizes, and preprocesses a single image.
    Returns None if the image cannot be read.
    """
    try:
        img = cv2.imread(image_path)
        if img is None:
            print(f"Warning: Could not read image {image_path}. Skipping.")
            return None
            
        img = cv2.resize(img, target_size)
        img_preprocessed = preprocess_input(img)
        return np.expand_dims(img_preprocessed, axis=0)
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return None

def predict_single_image(model, image_path):
    """
    Loads a single image, predicts it, and prints the result.
    """
    image_batch = load_and_prep_image(image_path)
    if image_batch is None: return

    print("Predicting...")
    prediction = model.predict(image_batch)
    
    predicted_index = np.argmax(prediction[0])
    predicted_label = LABELS[predicted_index]
    confidence = prediction[0][predicted_index] * 100

    print("\n--- Prediction Result ---")
    print(f"       File: {os.path.basename(image_path)}")
    print(f"Prediction is: {predicted_label.upper()}")
    print(f"  Confidence: {confidence:.2f}%")
    print("-------------------------")

def evaluate_folder(model, folder_path):
    """
    Recursively evaluates all images in a given folder.
    """
    print(f"Scanning folder: {folder_path}\nThis may take a while...")
    total_files = 0
    correct_predictions = 0
    
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if not filename.lower().endswith(('.png', '.jpg', '.jpeg')): continue
            true_label = os.path.basename(root).lower()
            if true_label not in LABELS: continue

            image_path = os.path.join(root, filename)
            image_batch = load_and_prep_image(image_path)
            if image_batch is None: continue
            
            total_files += 1
            prediction = model.predict(image_batch, verbose=0)
            predicted_index = np.argmax(prediction[0])
            predicted_label = LABELS[predicted_index]

            # --- MODIFICATION IS HERE ---
            confidence = prediction[0][predicted_index] * 100

            if predicted_label == true_label:
                correct_predictions += 1
                result = "CORRECT"
            else:
                result = "WRONG"
            
            # --- AND HERE ---
            print(f"  > File: {filename} | True: {true_label} | Predicted: {predicted_label} ({confidence:.2f}%)  [{result}]")

    if total_files > 0:
        accuracy = (correct_predictions / total_files) * 100
        print("\n--- Evaluation Summary ---")
        print(f"Total Images: {total_files}")
        print(f"Correct Predictions: {correct_predictions}")
        print(f"OVERALL ACCURACY: {accuracy:.2f}%")
        print("--------------------------")
    else:
        print("\nNo valid image files found in 'fake' or 'real' subdirectories.")

def main():
    parser = argparse.ArgumentParser(description='Predict if an image is real or fake.')
    parser.add_argument('--input_path', type=str, required=True, help='Path to an image file OR a folder.')
    parser.add_argument('--model_path', type=str, default='models/best_model.keras', help='Path to the saved model file.')
    args = parser.parse_args()

    if not os.path.exists(args.model_path):
        print(f"Error: Model file not found at {args.model_path}")
        return

    custom_objects = {"ModifiedBranch": ModifiedBranch, "MainBranch": MainBranch, "Attention": Attention}
    print("Loading model...")
    model = tf.keras.models.load_model(args.model_path, custom_objects=custom_objects)
    print("Model loaded.")

    if os.path.isfile(args.input_path):
        predict_single_image(model, args.input_path)
    elif os.path.isdir(args.input_path):
        evaluate_folder(model, args.input_path)
    else:
        print(f"Error: Input path is not a valid file or directory: {args.input_path}")

if __name__ == "__main__":
    main()
# Out:
# Overwriting predict.py

# %% [markdown]
# ### Running Prediction
#
# Use the command below to test your saved model. You will need to provide a valid path to an image from your dataset.

# %%
# Example of how to run prediction on a single image from your validation set.
# You will need to find a valid path to an image.

# !python predict.py --image "/kaggle/input/1000-videos-split/1000_videos/validation/fake/000_003_0.png"
# !python predict.py --input_path "/kaggle/input/1000-videos-split/1000_videos/test"
# Out:
# 2025-09-21 14:21:28.114446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758464488.136970   29351 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758464488.143910   29351 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading model...
# I0000 00:00:1758464492.338465   29351 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model loaded.
# Scanning folder: /kaggle/input/1000-videos-split/1000_videos/test
# This may take a while...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758464499.539748   29375 service.cc:148] XLA service 0x7f8dc80042d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758464499.539840   29375 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1758464499.901590   29375 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1758464501.690335   29375 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   > File: 113_983_1.png | True: fake | Predicted: fake (99.84%)  [CORRECT]
#   > File: 095_053_38.png | True: fake | Predicted: fake (84.83%)  [CORRECT]
#   > File: 089_065_4.png | True: fake | Predicted: fake (97.70%)  [CORRECT]
#   > File: 074_825_2.png | True: fake | Predicted: real (92.25%)  [WRONG]
#   > File: 076_079_0.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 096_101_3.png | True: fake | Predicted: fake (98.06%)  [CORRECT]
#   > File: 099_295_20.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 071_054_10.png | True: fake | Predicted: real (53.96%)  [WRONG]
#   > File: 091_116_5.png | True: fake | Predicted: fake (83.64%)  [CORRECT]
#   > File: 113_983_19.png | True: fake | Predicted: fake (99.93%)  [CORRECT]
#   > File: 078_955_12.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 113_983_5.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 080_061_6.png | True: fake | Predicted: fake (96.65%)  [CORRECT]
#   > File: 121_093_12.png | True: fake | Predicted: fake (67.16%)  [CORRECT]
#   > File: 127_129_26.png | True: fake | Predicted: fake (58.39%)  [CORRECT]
#   > File: 119_123_1.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 127_129_1.png | True: fake | Predicted: fake (93.04%)  [CORRECT]
#   > File: 068_028_4.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 091_116_15.png | True: fake | Predicted: fake (98.35%)  [CORRECT]
#   > File: 072_037_7.png | True: fake | Predicted: fake (89.96%)  [CORRECT]
#   > File: 116_091_5.png | True: fake | Predicted: fake (96.74%)  [CORRECT]
#   > File: 098_092_6.png | True: fake | Predicted: fake (99.93%)  [CORRECT]
#   > File: 114_102_20.png | True: fake | Predicted: fake (76.85%)  [CORRECT]
#   > File: 101_096_32.png | True: fake | Predicted: fake (99.77%)  [CORRECT]
#   > File: 095_053_26.png | True: fake | Predicted: real (81.01%)  [WRONG]
#   > File: 127_129_6.png | True: fake | Predicted: fake (99.38%)  [CORRECT]
#   > File: 081_087_11.png | True: fake | Predicted: fake (91.42%)  [CORRECT]
#   > File: 080_061_11.png | True: fake | Predicted: fake (99.27%)  [CORRECT]
#   > File: 127_129_15.png | True: fake | Predicted: fake (90.35%)  [CORRECT]
#   > File: 089_065_8.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 096_101_12.png | True: fake | Predicted: fake (94.21%)  [CORRECT]
#   > File: 083_213_8.png | True: fake | Predicted: fake (96.01%)  [CORRECT]
#   > File: 099_295_4.png | True: fake | Predicted: fake (99.22%)  [CORRECT]
#   > File: 106_198_6.png | True: fake | Predicted: fake (97.05%)  [CORRECT]
#   > File: 081_087_16.png | True: fake | Predicted: fake (85.23%)  [CORRECT]
#   > File: 100_077_4.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 086_090_9.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 118_120_10.png | True: fake | Predicted: fake (63.14%)  [CORRECT]
#   > File: 084_042_10.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 081_087_43.png | True: fake | Predicted: fake (93.75%)  [CORRECT]
#   > File: 117_217_17.png | True: fake | Predicted: fake (64.85%)  [CORRECT]
#   > File: 101_096_35.png | True: fake | Predicted: fake (98.82%)  [CORRECT]
#   > File: 094_111_10.png | True: fake | Predicted: fake (98.70%)  [CORRECT]
#   > File: 126_104_5.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 114_102_12.png | True: fake | Predicted: fake (97.49%)  [CORRECT]
#   > File: 117_217_2.png | True: fake | Predicted: fake (94.35%)  [CORRECT]
#   > File: 082_103_12.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 114_102_8.png | True: fake | Predicted: fake (99.82%)  [CORRECT]
#   > File: 078_955_8.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 107_109_1.png | True: fake | Predicted: fake (72.51%)  [CORRECT]
#   > File: 110_043_12.png | True: fake | Predicted: fake (96.40%)  [CORRECT]
#   > File: 082_103_6.png | True: fake | Predicted: fake (99.47%)  [CORRECT]
#   > File: 102_114_3.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 068_028_6.png | True: fake | Predicted: fake (99.72%)  [CORRECT]
#   > File: 107_109_16.png | True: fake | Predicted: fake (51.89%)  [CORRECT]
#   > File: 078_955_15.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 112_892_7.png | True: fake | Predicted: fake (69.51%)  [CORRECT]
#   > File: 090_086_16.png | True: fake | Predicted: fake (99.83%)  [CORRECT]
#   > File: 084_042_7.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 089_065_6.png | True: fake | Predicted: fake (99.95%)  [CORRECT]
#   > File: 101_096_23.png | True: fake | Predicted: fake (99.69%)  [CORRECT]
#   > File: 102_114_6.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 097_033_10.png | True: fake | Predicted: fake (66.82%)  [CORRECT]
#   > File: 099_295_22.png | True: fake | Predicted: fake (99.70%)  [CORRECT]
#   > File: 118_120_2.png | True: fake | Predicted: real (51.06%)  [WRONG]
#   > File: 088_060_15.png | True: fake | Predicted: real (67.65%)  [WRONG]
#   > File: 082_103_2.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 122_144_10.png | True: fake | Predicted: fake (99.34%)  [CORRECT]
#   > File: 077_100_16.png | True: fake | Predicted: real (55.72%)  [WRONG]
#   > File: 114_102_33.png | True: fake | Predicted: fake (59.62%)  [CORRECT]
#   > File: 102_114_14.png | True: fake | Predicted: fake (99.94%)  [CORRECT]
#   > File: 088_060_22.png | True: fake | Predicted: real (62.05%)  [WRONG]
#   > File: 106_198_4.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 101_096_15.png | True: fake | Predicted: fake (98.23%)  [CORRECT]
#   > File: 114_102_32.png | True: fake | Predicted: fake (57.23%)  [CORRECT]
#   > File: 102_114_5.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 086_090_16.png | True: fake | Predicted: fake (99.87%)  [CORRECT]
#   > File: 089_065_18.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 111_094_6.png | True: fake | Predicted: fake (67.99%)  [CORRECT]
#   > File: 095_053_36.png | True: fake | Predicted: real (61.95%)  [WRONG]
#   > File: 088_060_21.png | True: fake | Predicted: real (73.94%)  [WRONG]
#   > File: 116_091_8.png | True: fake | Predicted: fake (96.79%)  [CORRECT]
#   > File: 120_118_10.png | True: fake | Predicted: fake (99.42%)  [CORRECT]
#   > File: 110_043_9.png | True: fake | Predicted: fake (95.30%)  [CORRECT]
#   > File: 095_053_12.png | True: fake | Predicted: real (63.64%)  [WRONG]
#   > File: 114_102_36.png | True: fake | Predicted: fake (77.19%)  [CORRECT]
#   > File: 084_042_17.png | True: fake | Predicted: fake (99.53%)  [CORRECT]
#   > File: 121_093_2.png | True: fake | Predicted: fake (99.66%)  [CORRECT]
#   > File: 095_053_5.png | True: fake | Predicted: fake (55.08%)  [CORRECT]
#   > File: 114_102_5.png | True: fake | Predicted: fake (63.30%)  [CORRECT]
#   > File: 088_060_6.png | True: fake | Predicted: real (70.09%)  [WRONG]
#   > File: 076_079_6.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 103_082_17.png | True: fake | Predicted: fake (98.92%)  [CORRECT]
#   > File: 073_024_6.png | True: fake | Predicted: real (51.28%)  [WRONG]
#   > File: 075_977_15.png | True: fake | Predicted: fake (99.76%)  [CORRECT]
#   > File: 075_977_18.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 077_100_6.png | True: fake | Predicted: real (50.34%)  [WRONG]
#   > File: 096_101_15.png | True: fake | Predicted: fake (98.52%)  [CORRECT]
#   > File: 089_065_7.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 114_102_46.png | True: fake | Predicted: fake (64.18%)  [CORRECT]
#   > File: 087_081_1.png | True: fake | Predicted: fake (93.80%)  [CORRECT]
#   > File: 088_060_13.png | True: fake | Predicted: fake (76.27%)  [CORRECT]
#   > File: 080_061_3.png | True: fake | Predicted: fake (99.72%)  [CORRECT]
#   > File: 124_085_5.png | True: fake | Predicted: fake (98.72%)  [CORRECT]
#   > File: 107_109_8.png | True: fake | Predicted: fake (51.66%)  [CORRECT]
#   > File: 093_121_2.png | True: fake | Predicted: real (56.71%)  [WRONG]
#   > File: 101_096_0.png | True: fake | Predicted: fake (93.40%)  [CORRECT]
#   > File: 079_076_0.png | True: fake | Predicted: fake (90.52%)  [CORRECT]
#   > File: 106_198_11.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 096_101_0.png | True: fake | Predicted: fake (93.96%)  [CORRECT]
#   > File: 107_109_17.png | True: fake | Predicted: fake (62.33%)  [CORRECT]
#   > File: 087_081_3.png | True: fake | Predicted: fake (90.99%)  [CORRECT]
#   > File: 078_955_17.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 113_983_22.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 107_109_3.png | True: fake | Predicted: fake (65.10%)  [CORRECT]
#   > File: 114_102_13.png | True: fake | Predicted: fake (63.05%)  [CORRECT]
#   > File: 089_065_12.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 122_144_7.png | True: fake | Predicted: fake (99.60%)  [CORRECT]
#   > File: 073_024_26.png | True: fake | Predicted: real (75.93%)  [WRONG]
#   > File: 092_098_3.png | True: fake | Predicted: fake (66.77%)  [CORRECT]
#   > File: 114_102_15.png | True: fake | Predicted: fake (96.80%)  [CORRECT]
#   > File: 100_077_3.png | True: fake | Predicted: fake (98.84%)  [CORRECT]
#   > File: 103_082_6.png | True: fake | Predicted: fake (93.16%)  [CORRECT]
#   > File: 114_102_11.png | True: fake | Predicted: fake (94.36%)  [CORRECT]
#   > File: 125_038_2.png | True: fake | Predicted: fake (99.73%)  [CORRECT]
#   > File: 067_025_11.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 104_126_2.png | True: fake | Predicted: fake (89.62%)  [CORRECT]
#   > File: 090_086_5.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 111_094_16.png | True: fake | Predicted: fake (84.32%)  [CORRECT]
#   > File: 126_104_7.png | True: fake | Predicted: fake (99.14%)  [CORRECT]
#   > File: 073_024_12.png | True: fake | Predicted: real (59.55%)  [WRONG]
#   > File: 105_180_8.png | True: fake | Predicted: fake (97.60%)  [CORRECT]
#   > File: 069_961_22.png | True: fake | Predicted: fake (85.08%)  [CORRECT]
#   > File: 088_060_20.png | True: fake | Predicted: fake (60.45%)  [CORRECT]
#   > File: 121_093_13.png | True: fake | Predicted: real (52.57%)  [WRONG]
#   > File: 113_983_25.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 076_079_7.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 125_038_15.png | True: fake | Predicted: fake (99.91%)  [CORRECT]
#   > File: 113_983_21.png | True: fake | Predicted: fake (99.78%)  [CORRECT]
#   > File: 073_024_17.png | True: fake | Predicted: real (53.98%)  [WRONG]
#   > File: 103_082_1.png | True: fake | Predicted: fake (93.81%)  [CORRECT]
#   > File: 120_118_9.png | True: fake | Predicted: fake (98.12%)  [CORRECT]
#   > File: 081_087_27.png | True: fake | Predicted: fake (95.30%)  [CORRECT]
#   > File: 111_094_8.png | True: fake | Predicted: fake (86.15%)  [CORRECT]
#   > File: 069_961_1.png | True: fake | Predicted: fake (97.28%)  [CORRECT]
#   > File: 121_093_10.png | True: fake | Predicted: fake (95.25%)  [CORRECT]
#   > File: 067_025_15.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 099_295_18.png | True: fake | Predicted: fake (99.64%)  [CORRECT]
#   > File: 115_939_10.png | True: fake | Predicted: fake (96.69%)  [CORRECT]
#   > File: 086_090_12.png | True: fake | Predicted: fake (99.86%)  [CORRECT]
#   > File: 076_079_1.png | True: fake | Predicted: fake (99.96%)  [CORRECT]
#   > File: 125_038_16.png | True: fake | Predicted: fake (99.50%)  [CORRECT]
#   > File: 103_082_12.png | True: fake | Predicted: fake (99.52%)  [CORRECT]
#   > File: 118_120_9.png | True: fake | Predicted: fake (54.44%)  [CORRECT]
#   > File: 120_118_1.png | True: fake | Predicted: fake (98.63%)  [CORRECT]
#   > File: 108_052_4.png | True: fake | Predicted: fake (84.96%)  [CORRECT]
#   > File: 071_054_14.png | True: fake | Predicted: fake (60.86%)  [CORRECT]
#   > File: 098_092_10.png | True: fake | Predicted: fake (99.94%)  [CORRECT]
#   > File: 124_085_4.png | True: fake | Predicted: fake (90.13%)  [CORRECT]
#   > File: 075_977_5.png | True: fake | Predicted: fake (71.08%)  [CORRECT]
#   > File: 088_060_24.png | True: fake | Predicted: real (78.66%)  [WRONG]
#   > File: 086_090_8.png | True: fake | Predicted: fake (99.87%)  [CORRECT]
#   > File: 104_126_6.png | True: fake | Predicted: fake (91.29%)  [CORRECT]
#   > File: 127_129_5.png | True: fake | Predicted: fake (98.58%)  [CORRECT]
#   > File: 119_123_9.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 077_100_7.png | True: fake | Predicted: real (76.91%)  [WRONG]
#   > File: 068_028_3.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 074_825_3.png | True: fake | Predicted: real (71.81%)  [WRONG]
#   > File: 086_090_22.png | True: fake | Predicted: fake (98.84%)  [CORRECT]
#   > File: 095_053_0.png | True: fake | Predicted: real (55.64%)  [WRONG]
#   > File: 069_961_14.png | True: fake | Predicted: fake (99.87%)  [CORRECT]
#   > File: 088_060_12.png | True: fake | Predicted: fake (92.24%)  [CORRECT]
#   > File: 077_100_12.png | True: fake | Predicted: fake (76.31%)  [CORRECT]
#   > File: 073_024_20.png | True: fake | Predicted: real (62.33%)  [WRONG]
#   > File: 127_129_20.png | True: fake | Predicted: fake (96.62%)  [CORRECT]
#   > File: 078_955_13.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 077_100_8.png | True: fake | Predicted: real (61.61%)  [WRONG]
#   > File: 072_037_4.png | True: fake | Predicted: fake (99.35%)  [CORRECT]
#   > File: 069_961_6.png | True: fake | Predicted: fake (98.17%)  [CORRECT]
#   > File: 082_103_5.png | True: fake | Predicted: real (56.42%)  [WRONG]
#   > File: 092_098_17.png | True: fake | Predicted: fake (56.29%)  [CORRECT]
#   > File: 097_033_1.png | True: fake | Predicted: real (82.48%)  [WRONG]
#   > File: 091_116_4.png | True: fake | Predicted: fake (90.43%)  [CORRECT]
#   > File: 106_198_5.png | True: fake | Predicted: fake (99.34%)  [CORRECT]
#   > File: 076_079_9.png | True: fake | Predicted: fake (99.83%)  [CORRECT]
#   > File: 117_217_1.png | True: fake | Predicted: fake (83.54%)  [CORRECT]
#   > File: 122_144_5.png | True: fake | Predicted: fake (95.47%)  [CORRECT]
#   > File: 087_081_10.png | True: fake | Predicted: fake (92.79%)  [CORRECT]
#   > File: 070_057_0.png | True: fake | Predicted: fake (69.51%)  [CORRECT]
#   > File: 095_053_35.png | True: fake | Predicted: real (62.39%)  [WRONG]
#   > File: 108_052_0.png | True: fake | Predicted: real (75.98%)  [WRONG]
#   > File: 094_111_19.png | True: fake | Predicted: fake (99.84%)  [CORRECT]
#   > File: 104_126_10.png | True: fake | Predicted: fake (98.77%)  [CORRECT]
#   > File: 078_955_11.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 107_109_7.png | True: fake | Predicted: fake (70.92%)  [CORRECT]
#   > File: 109_107_0.png | True: fake | Predicted: fake (99.94%)  [CORRECT]
#   > File: 081_087_14.png | True: fake | Predicted: fake (94.28%)  [CORRECT]
#   > File: 117_217_21.png | True: fake | Predicted: fake (92.77%)  [CORRECT]
#   > File: 099_295_19.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 124_085_2.png | True: fake | Predicted: fake (99.82%)  [CORRECT]
#   > File: 121_093_16.png | True: fake | Predicted: real (50.23%)  [WRONG]
#   > File: 092_098_6.png | True: fake | Predicted: fake (83.98%)  [CORRECT]
#   > File: 099_295_23.png | True: fake | Predicted: fake (99.10%)  [CORRECT]
#   > File: 101_096_36.png | True: fake | Predicted: fake (96.97%)  [CORRECT]
#   > File: 082_103_16.png | True: fake | Predicted: fake (99.95%)  [CORRECT]
#   > File: 099_295_16.png | True: fake | Predicted: fake (99.96%)  [CORRECT]
#   > File: 127_129_21.png | True: fake | Predicted: fake (95.36%)  [CORRECT]
#   > File: 102_114_9.png | True: fake | Predicted: fake (99.61%)  [CORRECT]
#   > File: 097_033_2.png | True: fake | Predicted: real (65.88%)  [WRONG]
#   > File: 095_053_32.png | True: fake | Predicted: fake (57.30%)  [CORRECT]
#   > File: 098_092_8.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 079_076_10.png | True: fake | Predicted: fake (62.00%)  [CORRECT]
#   > File: 079_076_12.png | True: fake | Predicted: fake (69.06%)  [CORRECT]
#   > File: 070_057_2.png | True: fake | Predicted: fake (95.34%)  [CORRECT]
#   > File: 071_054_12.png | True: fake | Predicted: fake (86.41%)  [CORRECT]
#   > File: 114_102_38.png | True: fake | Predicted: fake (78.81%)  [CORRECT]
#   > File: 100_077_6.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 078_955_20.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 081_087_44.png | True: fake | Predicted: fake (84.73%)  [CORRECT]
#   > File: 109_107_7.png | True: fake | Predicted: fake (99.90%)  [CORRECT]
#   > File: 085_124_3.png | True: fake | Predicted: fake (96.95%)  [CORRECT]
#   > File: 084_042_23.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 069_961_17.png | True: fake | Predicted: fake (63.19%)  [CORRECT]
#   > File: 095_053_8.png | True: fake | Predicted: real (90.79%)  [WRONG]
#   > File: 104_126_7.png | True: fake | Predicted: fake (55.06%)  [CORRECT]
#   > File: 102_114_12.png | True: fake | Predicted: fake (99.78%)  [CORRECT]
#   > File: 088_060_10.png | True: fake | Predicted: fake (65.42%)  [CORRECT]
#   > File: 086_090_1.png | True: fake | Predicted: fake (99.12%)  [CORRECT]
#   > File: 107_109_5.png | True: fake | Predicted: real (52.45%)  [WRONG]
#   > File: 113_983_29.png | True: fake | Predicted: fake (99.47%)  [CORRECT]
#   > File: 122_144_4.png | True: fake | Predicted: fake (99.63%)  [CORRECT]
#   > File: 101_096_9.png | True: fake | Predicted: fake (96.35%)  [CORRECT]
#   > File: 073_024_13.png | True: fake | Predicted: real (52.07%)  [WRONG]
#   > File: 095_053_6.png | True: fake | Predicted: real (67.88%)  [WRONG]
#   > File: 112_892_5.png | True: fake | Predicted: fake (80.67%)  [CORRECT]
#   > File: 082_103_13.png | True: fake | Predicted: real (69.96%)  [WRONG]
#   > File: 079_076_13.png | True: fake | Predicted: fake (61.73%)  [CORRECT]
#   > File: 086_090_7.png | True: fake | Predicted: fake (99.85%)  [CORRECT]
#   > File: 119_123_12.png | True: fake | Predicted: fake (99.49%)  [CORRECT]
#   > File: 087_081_4.png | True: fake | Predicted: fake (99.70%)  [CORRECT]
#   > File: 115_939_9.png | True: fake | Predicted: fake (99.57%)  [CORRECT]
#   > File: 086_090_5.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 099_295_10.png | True: fake | Predicted: fake (95.08%)  [CORRECT]
#   > File: 096_101_2.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 105_180_6.png | True: fake | Predicted: fake (62.59%)  [CORRECT]
#   > File: 084_042_14.png | True: fake | Predicted: fake (99.32%)  [CORRECT]
#   > File: 080_061_0.png | True: fake | Predicted: fake (76.05%)  [CORRECT]
#   > File: 101_096_22.png | True: fake | Predicted: fake (92.94%)  [CORRECT]
#   > File: 121_093_4.png | True: fake | Predicted: real (52.01%)  [WRONG]
#   > File: 114_102_37.png | True: fake | Predicted: fake (80.38%)  [CORRECT]
#   > File: 086_090_17.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 073_024_25.png | True: fake | Predicted: real (54.41%)  [WRONG]
#   > File: 081_087_29.png | True: fake | Predicted: fake (93.63%)  [CORRECT]
#   > File: 101_096_7.png | True: fake | Predicted: fake (98.90%)  [CORRECT]
#   > File: 084_042_20.png | True: fake | Predicted: fake (99.72%)  [CORRECT]
#   > File: 108_052_8.png | True: fake | Predicted: fake (97.60%)  [CORRECT]
#   > File: 114_102_31.png | True: fake | Predicted: fake (89.27%)  [CORRECT]
#   > File: 114_102_24.png | True: fake | Predicted: fake (95.29%)  [CORRECT]
#   > File: 113_983_8.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 107_109_2.png | True: fake | Predicted: fake (80.35%)  [CORRECT]
#   > File: 074_825_5.png | True: fake | Predicted: real (61.61%)  [WRONG]
#   > File: 073_024_3.png | True: fake | Predicted: real (67.92%)  [WRONG]
#   > File: 073_024_24.png | True: fake | Predicted: real (51.80%)  [WRONG]
#   > File: 089_065_1.png | True: fake | Predicted: fake (99.91%)  [CORRECT]
#   > File: 101_096_4.png | True: fake | Predicted: fake (99.78%)  [CORRECT]
#   > File: 086_090_30.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 121_093_21.png | True: fake | Predicted: fake (51.03%)  [CORRECT]
#   > File: 080_061_13.png | True: fake | Predicted: fake (99.86%)  [CORRECT]
#   > File: 069_961_21.png | True: fake | Predicted: fake (69.11%)  [CORRECT]
#   > File: 095_053_4.png | True: fake | Predicted: real (67.33%)  [WRONG]
#   > File: 104_126_0.png | True: fake | Predicted: fake (73.94%)  [CORRECT]
#   > File: 081_087_18.png | True: fake | Predicted: fake (92.09%)  [CORRECT]
#   > File: 112_892_11.png | True: fake | Predicted: fake (95.70%)  [CORRECT]
#   > File: 122_144_6.png | True: fake | Predicted: fake (98.52%)  [CORRECT]
#   > File: 120_118_14.png | True: fake | Predicted: fake (99.56%)  [CORRECT]
#   > File: 114_102_7.png | True: fake | Predicted: fake (68.00%)  [CORRECT]
#   > File: 083_213_2.png | True: fake | Predicted: fake (98.65%)  [CORRECT]
#   > File: 075_977_3.png | True: fake | Predicted: fake (95.72%)  [CORRECT]
#   > File: 114_102_19.png | True: fake | Predicted: fake (86.04%)  [CORRECT]
#   > File: 097_033_13.png | True: fake | Predicted: real (72.95%)  [WRONG]
#   > File: 121_093_14.png | True: fake | Predicted: real (62.03%)  [WRONG]
#   > File: 071_054_6.png | True: fake | Predicted: real (55.54%)  [WRONG]
#   > File: 095_053_28.png | True: fake | Predicted: real (52.94%)  [WRONG]
#   > File: 113_983_15.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 080_061_18.png | True: fake | Predicted: fake (99.81%)  [CORRECT]
#   > File: 095_053_17.png | True: fake | Predicted: real (85.46%)  [WRONG]
#   > File: 122_144_2.png | True: fake | Predicted: fake (98.98%)  [CORRECT]
#   > File: 093_121_4.png | True: fake | Predicted: fake (52.89%)  [CORRECT]
#   > File: 071_054_3.png | True: fake | Predicted: real (55.43%)  [WRONG]
#   > File: 080_061_12.png | True: fake | Predicted: fake (99.54%)  [CORRECT]
#   > File: 125_038_12.png | True: fake | Predicted: fake (99.93%)  [CORRECT]
#   > File: 094_111_8.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 083_213_12.png | True: fake | Predicted: fake (96.52%)  [CORRECT]
#   > File: 096_101_10.png | True: fake | Predicted: fake (97.97%)  [CORRECT]
#   > File: 087_081_6.png | True: fake | Predicted: fake (86.58%)  [CORRECT]
#   > File: 115_939_6.png | True: fake | Predicted: fake (99.39%)  [CORRECT]
#   > File: 096_101_7.png | True: fake | Predicted: fake (97.56%)  [CORRECT]
#   > File: 114_102_16.png | True: fake | Predicted: fake (75.71%)  [CORRECT]
#   > File: 099_295_15.png | True: fake | Predicted: fake (99.60%)  [CORRECT]
#   > File: 081_087_25.png | True: fake | Predicted: fake (93.04%)  [CORRECT]
#   > File: 119_123_13.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 101_096_27.png | True: fake | Predicted: fake (98.88%)  [CORRECT]
#   > File: 083_213_13.png | True: fake | Predicted: fake (96.45%)  [CORRECT]
#   > File: 070_057_12.png | True: fake | Predicted: real (57.20%)  [WRONG]
#   > File: 072_037_5.png | True: fake | Predicted: fake (95.19%)  [CORRECT]
#   > File: 114_102_2.png | True: fake | Predicted: fake (81.67%)  [CORRECT]
#   > File: 107_109_21.png | True: fake | Predicted: fake (61.20%)  [CORRECT]
#   > File: 078_955_10.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 076_079_2.png | True: fake | Predicted: fake (99.06%)  [CORRECT]
#   > File: 087_081_9.png | True: fake | Predicted: fake (98.82%)  [CORRECT]
#   > File: 095_053_3.png | True: fake | Predicted: real (61.82%)  [WRONG]
#   > File: 101_096_26.png | True: fake | Predicted: fake (95.11%)  [CORRECT]
#   > File: 090_086_11.png | True: fake | Predicted: fake (95.90%)  [CORRECT]
#   > File: 105_180_2.png | True: fake | Predicted: fake (80.34%)  [CORRECT]
#   > File: 074_825_11.png | True: fake | Predicted: real (77.39%)  [WRONG]
#   > File: 080_061_2.png | True: fake | Predicted: fake (99.38%)  [CORRECT]
#   > File: 078_955_5.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 068_028_5.png | True: fake | Predicted: fake (99.85%)  [CORRECT]
#   > File: 077_100_11.png | True: fake | Predicted: fake (57.48%)  [CORRECT]
#   > File: 106_198_2.png | True: fake | Predicted: fake (99.70%)  [CORRECT]
#   > File: 127_129_14.png | True: fake | Predicted: fake (77.97%)  [CORRECT]
#   > File: 116_091_6.png | True: fake | Predicted: fake (99.10%)  [CORRECT]
#   > File: 095_053_7.png | True: fake | Predicted: real (54.89%)  [WRONG]
#   > File: 099_295_9.png | True: fake | Predicted: fake (99.90%)  [CORRECT]
#   > File: 100_077_15.png | True: fake | Predicted: fake (99.94%)  [CORRECT]
#   > File: 094_111_24.png | True: fake | Predicted: fake (93.13%)  [CORRECT]
#   > File: 099_295_13.png | True: fake | Predicted: fake (99.33%)  [CORRECT]
#   > File: 098_092_0.png | True: fake | Predicted: fake (99.83%)  [CORRECT]
#   > File: 107_109_0.png | True: fake | Predicted: fake (65.26%)  [CORRECT]
#   > File: 112_892_0.png | True: fake | Predicted: fake (58.18%)  [CORRECT]
#   > File: 114_102_28.png | True: fake | Predicted: fake (67.24%)  [CORRECT]
#   > File: 095_053_15.png | True: fake | Predicted: fake (50.71%)  [CORRECT]
#   > File: 127_129_9.png | True: fake | Predicted: fake (83.84%)  [CORRECT]
#   > File: 078_955_16.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 069_961_7.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 086_090_27.png | True: fake | Predicted: fake (99.68%)  [CORRECT]
#   > File: 113_983_33.png | True: fake | Predicted: fake (99.85%)  [CORRECT]
#   > File: 071_054_0.png | True: fake | Predicted: fake (60.43%)  [CORRECT]
#   > File: 111_094_10.png | True: fake | Predicted: fake (74.54%)  [CORRECT]
#   > File: 079_076_8.png | True: fake | Predicted: fake (91.96%)  [CORRECT]
#   > File: 107_109_13.png | True: fake | Predicted: fake (88.57%)  [CORRECT]
#   > File: 089_065_2.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 101_096_21.png | True: fake | Predicted: fake (82.06%)  [CORRECT]
#   > File: 113_983_4.png | True: fake | Predicted: fake (99.76%)  [CORRECT]
#   > File: 081_087_9.png | True: fake | Predicted: fake (96.20%)  [CORRECT]
#   > File: 113_983_27.png | True: fake | Predicted: fake (99.14%)  [CORRECT]
#   > File: 074_825_12.png | True: fake | Predicted: real (69.53%)  [WRONG]
#   > File: 074_825_13.png | True: fake | Predicted: real (75.30%)  [WRONG]
#   > File: 109_107_10.png | True: fake | Predicted: fake (99.56%)  [CORRECT]
#   > File: 081_087_20.png | True: fake | Predicted: fake (93.69%)  [CORRECT]
#   > File: 097_033_5.png | True: fake | Predicted: real (50.34%)  [WRONG]
#   > File: 089_065_9.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 068_028_1.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 088_060_11.png | True: fake | Predicted: fake (55.96%)  [CORRECT]
#   > File: 091_116_11.png | True: fake | Predicted: fake (99.17%)  [CORRECT]
#   > File: 095_053_18.png | True: fake | Predicted: real (65.51%)  [WRONG]
#   > File: 088_060_18.png | True: fake | Predicted: real (57.63%)  [WRONG]
#   > File: 124_085_12.png | True: fake | Predicted: fake (98.44%)  [CORRECT]
#   > File: 127_129_0.png | True: fake | Predicted: fake (99.95%)  [CORRECT]
#   > File: 069_961_8.png | True: fake | Predicted: fake (90.25%)  [CORRECT]
#   > File: 077_100_21.png | True: fake | Predicted: real (60.15%)  [WRONG]
#   > File: 118_120_7.png | True: fake | Predicted: fake (64.98%)  [CORRECT]
#   > File: 103_082_10.png | True: fake | Predicted: fake (92.35%)  [CORRECT]
#   > File: 075_977_11.png | True: fake | Predicted: fake (99.66%)  [CORRECT]
#   > File: 102_114_13.png | True: fake | Predicted: fake (99.91%)  [CORRECT]
#   > File: 113_983_0.png | True: fake | Predicted: fake (99.89%)  [CORRECT]
#   > File: 112_892_6.png | True: fake | Predicted: fake (67.46%)  [CORRECT]
#   > File: 107_109_4.png | True: fake | Predicted: real (50.54%)  [WRONG]
#   > File: 103_082_20.png | True: fake | Predicted: fake (58.10%)  [CORRECT]
#   > File: 100_077_5.png | True: fake | Predicted: fake (99.66%)  [CORRECT]
#   > File: 068_028_2.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 117_217_3.png | True: fake | Predicted: fake (84.15%)  [CORRECT]
#   > File: 127_129_22.png | True: fake | Predicted: fake (96.67%)  [CORRECT]
#   > File: 121_093_0.png | True: fake | Predicted: fake (59.62%)  [CORRECT]
#   > File: 081_087_2.png | True: fake | Predicted: fake (90.86%)  [CORRECT]
#   > File: 102_114_11.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 124_085_11.png | True: fake | Predicted: fake (98.82%)  [CORRECT]
#   > File: 095_053_2.png | True: fake | Predicted: real (60.18%)  [WRONG]
#   > File: 108_052_5.png | True: fake | Predicted: fake (78.42%)  [CORRECT]
#   > File: 114_102_48.png | True: fake | Predicted: fake (69.45%)  [CORRECT]
#   > File: 077_100_14.png | True: fake | Predicted: fake (51.04%)  [CORRECT]
#   > File: 085_124_5.png | True: fake | Predicted: fake (85.82%)  [CORRECT]
#   > File: 117_217_7.png | True: fake | Predicted: fake (65.21%)  [CORRECT]
#   > File: 095_053_13.png | True: fake | Predicted: fake (59.55%)  [CORRECT]
#   > File: 111_094_7.png | True: fake | Predicted: fake (51.27%)  [CORRECT]
#   > File: 094_111_25.png | True: fake | Predicted: fake (99.57%)  [CORRECT]
#   > File: 112_892_12.png | True: fake | Predicted: fake (83.39%)  [CORRECT]
#   > File: 069_961_5.png | True: fake | Predicted: fake (93.16%)  [CORRECT]
#   > File: 105_180_9.png | True: fake | Predicted: fake (87.09%)  [CORRECT]
#   > File: 110_043_5.png | True: fake | Predicted: fake (97.28%)  [CORRECT]
#   > File: 082_103_1.png | True: fake | Predicted: fake (99.87%)  [CORRECT]
#   > File: 101_096_31.png | True: fake | Predicted: fake (96.34%)  [CORRECT]
#   > File: 069_961_15.png | True: fake | Predicted: fake (89.58%)  [CORRECT]
#   > File: 103_082_19.png | True: fake | Predicted: fake (80.95%)  [CORRECT]
#   > File: 125_038_10.png | True: fake | Predicted: fake (99.55%)  [CORRECT]
#   > File: 124_085_9.png | True: fake | Predicted: fake (64.09%)  [CORRECT]
#   > File: 114_102_18.png | True: fake | Predicted: fake (92.88%)  [CORRECT]
#   > File: 096_101_5.png | True: fake | Predicted: fake (99.94%)  [CORRECT]
#   > File: 115_939_1.png | True: fake | Predicted: fake (99.37%)  [CORRECT]
#   > File: 116_091_7.png | True: fake | Predicted: fake (75.84%)  [CORRECT]
#   > File: 099_295_1.png | True: fake | Predicted: fake (99.53%)  [CORRECT]
#   > File: 116_091_2.png | True: fake | Predicted: fake (72.86%)  [CORRECT]
#   > File: 080_061_1.png | True: fake | Predicted: fake (99.15%)  [CORRECT]
#   > File: 085_124_2.png | True: fake | Predicted: fake (99.85%)  [CORRECT]
#   > File: 126_104_3.png | True: fake | Predicted: real (53.70%)  [WRONG]
#   > File: 089_065_19.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 127_129_10.png | True: fake | Predicted: fake (92.59%)  [CORRECT]
#   > File: 115_939_7.png | True: fake | Predicted: fake (99.29%)  [CORRECT]
#   > File: 071_054_1.png | True: fake | Predicted: fake (58.21%)  [CORRECT]
#   > File: 118_120_12.png | True: fake | Predicted: fake (81.89%)  [CORRECT]
#   > File: 082_103_8.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 086_090_20.png | True: fake | Predicted: fake (97.57%)  [CORRECT]
#   > File: 091_116_19.png | True: fake | Predicted: fake (99.69%)  [CORRECT]
#   > File: 099_295_12.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 067_025_16.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 094_111_20.png | True: fake | Predicted: fake (99.87%)  [CORRECT]
#   > File: 078_955_2.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 090_086_3.png | True: fake | Predicted: fake (98.63%)  [CORRECT]
#   > File: 101_096_1.png | True: fake | Predicted: fake (99.49%)  [CORRECT]
#   > File: 073_024_19.png | True: fake | Predicted: real (56.35%)  [WRONG]
#   > File: 125_038_7.png | True: fake | Predicted: fake (99.07%)  [CORRECT]
#   > File: 097_033_14.png | True: fake | Predicted: real (55.40%)  [WRONG]
#   > File: 094_111_0.png | True: fake | Predicted: fake (98.95%)  [CORRECT]
#   > File: 073_024_7.png | True: fake | Predicted: real (64.30%)  [WRONG]
#   > File: 080_061_15.png | True: fake | Predicted: fake (99.69%)  [CORRECT]
#   > File: 095_053_14.png | True: fake | Predicted: fake (84.97%)  [CORRECT]
#   > File: 105_180_0.png | True: fake | Predicted: fake (73.85%)  [CORRECT]
#   > File: 068_028_8.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 085_124_6.png | True: fake | Predicted: fake (80.05%)  [CORRECT]
#   > File: 080_061_14.png | True: fake | Predicted: fake (98.63%)  [CORRECT]
#   > File: 068_028_9.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 121_093_17.png | True: fake | Predicted: real (54.47%)  [WRONG]
#   > File: 117_217_16.png | True: fake | Predicted: fake (50.82%)  [CORRECT]
#   > File: 117_217_12.png | True: fake | Predicted: fake (95.08%)  [CORRECT]
#   > File: 078_955_7.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 117_217_8.png | True: fake | Predicted: fake (80.39%)  [CORRECT]
#   > File: 083_213_1.png | True: fake | Predicted: fake (97.74%)  [CORRECT]
#   > File: 114_102_10.png | True: fake | Predicted: fake (98.68%)  [CORRECT]
#   > File: 080_061_10.png | True: fake | Predicted: fake (91.77%)  [CORRECT]
#   > File: 089_065_25.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 091_116_20.png | True: fake | Predicted: fake (97.61%)  [CORRECT]
#   > File: 104_126_4.png | True: fake | Predicted: fake (78.75%)  [CORRECT]
#   > File: 105_180_5.png | True: fake | Predicted: fake (81.63%)  [CORRECT]
#   > File: 102_114_1.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 095_053_30.png | True: fake | Predicted: real (84.61%)  [WRONG]
#   > File: 113_983_10.png | True: fake | Predicted: real (59.58%)  [WRONG]
#   > File: 094_111_23.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 083_213_0.png | True: fake | Predicted: fake (99.81%)  [CORRECT]
#   > File: 119_123_5.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 083_213_6.png | True: fake | Predicted: fake (94.04%)  [CORRECT]
#   > File: 086_090_4.png | True: fake | Predicted: fake (99.76%)  [CORRECT]
#   > File: 069_961_0.png | True: fake | Predicted: fake (99.85%)  [CORRECT]
#   > File: 081_087_36.png | True: fake | Predicted: fake (95.52%)  [CORRECT]
#   > File: 110_043_3.png | True: fake | Predicted: fake (94.79%)  [CORRECT]
#   > File: 101_096_13.png | True: fake | Predicted: fake (98.47%)  [CORRECT]
#   > File: 112_892_3.png | True: fake | Predicted: fake (59.19%)  [CORRECT]
#   > File: 095_053_22.png | True: fake | Predicted: real (58.54%)  [WRONG]
#   > File: 094_111_6.png | True: fake | Predicted: fake (99.54%)  [CORRECT]
#   > File: 089_065_28.png | True: fake | Predicted: fake (99.81%)  [CORRECT]
#   > File: 084_042_1.png | True: fake | Predicted: fake (99.62%)  [CORRECT]
#   > File: 084_042_6.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 094_111_12.png | True: fake | Predicted: fake (97.42%)  [CORRECT]
#   > File: 108_052_6.png | True: fake | Predicted: fake (88.48%)  [CORRECT]
#   > File: 067_025_4.png | True: fake | Predicted: fake (95.33%)  [CORRECT]
#   > File: 091_116_10.png | True: fake | Predicted: fake (99.25%)  [CORRECT]
#   > File: 094_111_13.png | True: fake | Predicted: real (56.77%)  [WRONG]
#   > File: 119_123_2.png | True: fake | Predicted: fake (99.82%)  [CORRECT]
#   > File: 114_102_30.png | True: fake | Predicted: fake (87.74%)  [CORRECT]
#   > File: 123_119_11.png | True: fake | Predicted: fake (51.73%)  [CORRECT]
#   > File: 089_065_24.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 111_094_5.png | True: fake | Predicted: fake (97.16%)  [CORRECT]
#   > File: 123_119_13.png | True: fake | Predicted: fake (69.01%)  [CORRECT]
#   > File: 100_077_2.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 103_082_4.png | True: fake | Predicted: fake (99.72%)  [CORRECT]
#   > File: 092_098_11.png | True: fake | Predicted: real (57.54%)  [WRONG]
#   > File: 084_042_16.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 093_121_6.png | True: fake | Predicted: fake (98.80%)  [CORRECT]
#   > File: 071_054_2.png | True: fake | Predicted: fake (95.08%)  [CORRECT]
#   > File: 082_103_4.png | True: fake | Predicted: fake (99.78%)  [CORRECT]
#   > File: 090_086_22.png | True: fake | Predicted: fake (50.26%)  [CORRECT]
#   > File: 114_102_44.png | True: fake | Predicted: fake (78.37%)  [CORRECT]
#   > File: 086_090_25.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 094_111_18.png | True: fake | Predicted: fake (99.33%)  [CORRECT]
#   > File: 114_102_41.png | True: fake | Predicted: fake (80.87%)  [CORRECT]
#   > File: 127_129_19.png | True: fake | Predicted: fake (70.80%)  [CORRECT]
#   > File: 110_043_0.png | True: fake | Predicted: fake (90.73%)  [CORRECT]
#   > File: 126_104_1.png | True: fake | Predicted: fake (85.17%)  [CORRECT]
#   > File: 097_033_0.png | True: fake | Predicted: real (59.22%)  [WRONG]
#   > File: 092_098_8.png | True: fake | Predicted: fake (68.58%)  [CORRECT]
#   > File: 090_086_8.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 102_114_8.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 088_060_3.png | True: fake | Predicted: fake (52.35%)  [CORRECT]
#   > File: 115_939_2.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 078_955_4.png | True: fake | Predicted: fake (98.47%)  [CORRECT]
#   > File: 103_082_21.png | True: fake | Predicted: real (74.94%)  [WRONG]
#   > File: 085_124_10.png | True: fake | Predicted: fake (99.76%)  [CORRECT]
#   > File: 120_118_6.png | True: fake | Predicted: fake (99.67%)  [CORRECT]
#   > File: 113_983_24.png | True: fake | Predicted: fake (98.59%)  [CORRECT]
#   > File: 097_033_3.png | True: fake | Predicted: real (58.63%)  [WRONG]
#   > File: 090_086_4.png | True: fake | Predicted: fake (99.93%)  [CORRECT]
#   > File: 075_977_17.png | True: fake | Predicted: fake (99.96%)  [CORRECT]
#   > File: 110_043_13.png | True: fake | Predicted: fake (53.02%)  [CORRECT]
#   > File: 092_098_9.png | True: fake | Predicted: fake (74.91%)  [CORRECT]
#   > File: 083_213_4.png | True: fake | Predicted: fake (90.33%)  [CORRECT]
#   > File: 121_093_20.png | True: fake | Predicted: fake (83.61%)  [CORRECT]
#   > File: 120_118_4.png | True: fake | Predicted: fake (99.52%)  [CORRECT]
#   > File: 094_111_11.png | True: fake | Predicted: real (53.88%)  [WRONG]
#   > File: 119_123_10.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 069_961_9.png | True: fake | Predicted: fake (99.99%)  [CORRECT]
#   > File: 110_043_7.png | True: fake | Predicted: real (52.27%)  [WRONG]
#   > File: 111_094_4.png | True: fake | Predicted: fake (97.90%)  [CORRECT]
#   > File: 120_118_11.png | True: fake | Predicted: fake (99.53%)  [CORRECT]
#   > File: 099_295_8.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 112_892_10.png | True: fake | Predicted: fake (67.52%)  [CORRECT]
#   > File: 111_094_0.png | True: fake | Predicted: fake (58.28%)  [CORRECT]
#   > File: 082_103_10.png | True: fake | Predicted: fake (99.82%)  [CORRECT]
#   > File: 073_024_5.png | True: fake | Predicted: real (66.83%)  [WRONG]
#   > File: 103_082_18.png | True: fake | Predicted: fake (95.79%)  [CORRECT]
#   > File: 087_081_0.png | True: fake | Predicted: fake (66.38%)  [CORRECT]
#   > File: 123_119_14.png | True: fake | Predicted: fake (51.22%)  [CORRECT]
#   > File: 119_123_3.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 069_961_12.png | True: fake | Predicted: fake (99.93%)  [CORRECT]
#   > File: 067_025_3.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 082_103_7.png | True: fake | Predicted: real (52.09%)  [WRONG]
#   > File: 110_043_11.png | True: fake | Predicted: fake (52.26%)  [CORRECT]
#   > File: 109_107_11.png | True: fake | Predicted: fake (99.82%)  [CORRECT]
#   > File: 079_076_3.png | True: fake | Predicted: fake (95.99%)  [CORRECT]
#   > File: 081_087_34.png | True: fake | Predicted: fake (94.52%)  [CORRECT]
#   > File: 126_104_2.png | True: fake | Predicted: fake (97.62%)  [CORRECT]
#   > File: 077_100_23.png | True: fake | Predicted: fake (52.99%)  [CORRECT]
#   > File: 072_037_0.png | True: fake | Predicted: fake (66.55%)  [CORRECT]
#   > File: 113_983_23.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 074_825_1.png | True: fake | Predicted: real (82.15%)  [WRONG]
#   > File: 070_057_13.png | True: fake | Predicted: fake (96.13%)  [CORRECT]
#   > File: 089_065_14.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 088_060_19.png | True: fake | Predicted: fake (87.17%)  [CORRECT]
#   > File: 095_053_34.png | True: fake | Predicted: fake (59.99%)  [CORRECT]
#   > File: 106_198_9.png | True: fake | Predicted: fake (99.91%)  [CORRECT]
#   > File: 127_129_3.png | True: fake | Predicted: fake (97.67%)  [CORRECT]
#   > File: 077_100_10.png | True: fake | Predicted: fake (51.38%)  [CORRECT]
#   > File: 118_120_4.png | True: fake | Predicted: fake (59.60%)  [CORRECT]
#   > File: 126_104_0.png | True: fake | Predicted: fake (78.11%)  [CORRECT]
#   > File: 080_061_5.png | True: fake | Predicted: fake (88.04%)  [CORRECT]
#   > File: 113_983_9.png | True: fake | Predicted: fake (99.95%)  [CORRECT]
#   > File: 094_111_5.png | True: fake | Predicted: fake (99.86%)  [CORRECT]
#   > File: 103_082_15.png | True: fake | Predicted: fake (95.37%)  [CORRECT]
#   > File: 103_082_0.png | True: fake | Predicted: fake (74.41%)  [CORRECT]
#   > File: 075_977_6.png | True: fake | Predicted: fake (99.84%)  [CORRECT]
#   > File: 087_081_5.png | True: fake | Predicted: fake (94.25%)  [CORRECT]
#   > File: 106_198_10.png | True: fake | Predicted: fake (97.51%)  [CORRECT]
#   > File: 099_295_5.png | True: fake | Predicted: fake (99.90%)  [CORRECT]
#   > File: 089_065_17.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 081_087_13.png | True: fake | Predicted: fake (88.01%)  [CORRECT]
#   > File: 088_060_8.png | True: fake | Predicted: real (54.85%)  [WRONG]
#   > File: 114_102_29.png | True: fake | Predicted: fake (81.66%)  [CORRECT]
#   > File: 114_102_27.png | True: fake | Predicted: fake (78.73%)  [CORRECT]
#   > File: 101_096_3.png | True: fake | Predicted: fake (98.54%)  [CORRECT]
#   > File: 088_060_9.png | True: fake | Predicted: real (76.59%)  [WRONG]
#   > File: 070_057_5.png | True: fake | Predicted: fake (99.93%)  [CORRECT]
#   > File: 084_042_3.png | True: fake | Predicted: fake (99.90%)  [CORRECT]
#   > File: 120_118_5.png | True: fake | Predicted: fake (98.31%)  [CORRECT]
#   > File: 098_092_5.png | True: fake | Predicted: fake (99.87%)  [CORRECT]
#   > File: 081_087_31.png | True: fake | Predicted: fake (57.96%)  [CORRECT]
#   > File: 127_129_18.png | True: fake | Predicted: fake (97.57%)  [CORRECT]
#   > File: 098_092_1.png | True: fake | Predicted: fake (99.46%)  [CORRECT]
#   > File: 079_076_11.png | True: fake | Predicted: fake (90.69%)  [CORRECT]
#   > File: 067_025_14.png | True: fake | Predicted: fake (99.41%)  [CORRECT]
#   > File: 113_983_16.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 085_124_7.png | True: fake | Predicted: fake (95.59%)  [CORRECT]
#   > File: 072_037_2.png | True: fake | Predicted: fake (86.30%)  [CORRECT]
#   > File: 097_033_12.png | True: fake | Predicted: real (59.48%)  [WRONG]
#   > File: 091_116_6.png | True: fake | Predicted: fake (98.69%)  [CORRECT]
#   > File: 104_126_13.png | True: fake | Predicted: fake (93.16%)  [CORRECT]
#   > File: 091_116_13.png | True: fake | Predicted: fake (94.95%)  [CORRECT]
#   > File: 109_107_3.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 092_098_10.png | True: fake | Predicted: fake (54.29%)  [CORRECT]
#   > File: 107_109_9.png | True: fake | Predicted: real (50.39%)  [WRONG]
#   > File: 124_085_0.png | True: fake | Predicted: fake (87.92%)  [CORRECT]
#   > File: 115_939_5.png | True: fake | Predicted: fake (99.95%)  [CORRECT]
#   > File: 073_024_21.png | True: fake | Predicted: real (58.19%)  [WRONG]
#   > File: 081_087_10.png | True: fake | Predicted: fake (97.68%)  [CORRECT]
#   > File: 090_086_10.png | True: fake | Predicted: fake (99.60%)  [CORRECT]
#   > File: 072_037_8.png | True: fake | Predicted: fake (88.99%)  [CORRECT]
#   > File: 124_085_10.png | True: fake | Predicted: fake (97.55%)  [CORRECT]
#   > File: 101_096_28.png | True: fake | Predicted: fake (98.20%)  [CORRECT]
#   > File: 083_213_10.png | True: fake | Predicted: fake (99.94%)  [CORRECT]
#   > File: 125_038_13.png | True: fake | Predicted: fake (98.53%)  [CORRECT]
#   > File: 100_077_9.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 069_961_23.png | True: fake | Predicted: fake (92.98%)  [CORRECT]
#   > File: 089_065_0.png | True: fake | Predicted: fake (99.32%)  [CORRECT]
#   > File: 078_955_9.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 089_065_15.png | True: fake | Predicted: fake (99.96%)  [CORRECT]
#   > File: 123_119_16.png | True: fake | Predicted: fake (69.12%)  [CORRECT]
#   > File: 073_024_22.png | True: fake | Predicted: real (61.38%)  [WRONG]
#   > File: 125_038_11.png | True: fake | Predicted: fake (99.97%)  [CORRECT]
#   > File: 117_217_4.png | True: fake | Predicted: fake (63.38%)  [CORRECT]
#   > File: 087_081_11.png | True: fake | Predicted: fake (94.81%)  [CORRECT]
#   > File: 109_107_5.png | True: fake | Predicted: fake (99.92%)  [CORRECT]
#   > File: 105_180_3.png | True: fake | Predicted: fake (98.83%)  [CORRECT]
#   > File: 114_102_40.png | True: fake | Predicted: fake (75.85%)  [CORRECT]
#   > File: 084_042_13.png | True: fake | Predicted: fake (99.98%)  [CORRECT]
#   > File: 108_052_3.png | True: fake | Predicted: fake (57.26%)  [CORRECT]
#   > File: 105_180_7.png | True: fake | Predicted: fake (92.42%)  [CORRECT]
#   > File: 102_114_7.png | True: fake | Predicted: fake (99.69%)  [CORRECT]
#   > File: 123_119_3.png | True: fake | Predicted: fake (51.52%)  [CORRECT]
#   > File: 084_042_18.png | True: fake | Predicted: fake (98.17%)  [CORRECT]
#   > File: 086_090_13.png | True: fake | Predicted: fake (99.62%)  [CORRECT]
#   > File: 086_090_24.png | True: fake | Predicted: fake (99.96%)  [CORRECT]
#   > File: 110_043_16.png | True: fake | Predicted: fake (98.35%)  [CORRECT]
#   > File: 089_065_21.png | True: fake | Predicted: fake (100.00%)  [CORRECT]
#   > File: 101_096_12.png | True: fake | Predicted: fake (85.07%)  [CORRECT]
#   > File: 097_033_8.png | True: fake | Predicted: real (68.11%)  [WRONG]
#   > File: 099_295_2.png | True: fake | Predicted: fake (99.78%)  [CORRECT]
#   > File: 108_052_9.png | True: fake | Predicted: fake (96.04%)  [CORRECT]
#   > File: 121_093_15.png | True: fake | Predicted: real (54.61%)  [WRONG]
# ...
#   > File: 127_14.png | True: real | Predicted: real (87.45%)  [CORRECT]
#   > File: 069_1.png | True: real | Predicted: real (94.66%)  [CORRECT]
#   > File: 090_5.png | True: real | Predicted: real (94.69%)  [CORRECT]
#   > File: 093_11.png | True: real | Predicted: real (89.88%)  [CORRECT]
#   > File: 081_21.png | True: real | Predicted: real (75.40%)  [CORRECT]
#   > File: 072_1.png | True: real | Predicted: real (80.19%)  [CORRECT]
#   > File: 081_13.png | True: real | Predicted: real (91.71%)  [CORRECT]
#   > File: 107_7.png | True: real | Predicted: real (58.68%)  [CORRECT]
#   > File: 093_8.png | True: real | Predicted: real (97.33%)  [CORRECT]
#   > File: 068_3.png | True: real | Predicted: real (61.20%)  [CORRECT]
#   > File: 128_18.png | True: real | Predicted: real (55.93%)  [CORRECT]
#   > File: 095_14.png | True: real | Predicted: real (80.07%)  [CORRECT]
#   > File: 117_7.png | True: real | Predicted: real (94.08%)  [CORRECT]
#   > File: 086_22.png | True: real | Predicted: real (85.22%)  [CORRECT]
#   > File: 082_11.png | True: real | Predicted: real (62.72%)  [CORRECT]
#   > File: 117_5.png | True: real | Predicted: real (95.41%)  [CORRECT]
#   > File: 105_6.png | True: real | Predicted: real (73.59%)  [CORRECT]
#   > File: 116_7.png | True: real | Predicted: real (68.18%)  [CORRECT]
#   > File: 099_13.png | True: real | Predicted: real (84.48%)  [CORRECT]
#   > File: 123_3.png | True: real | Predicted: real (63.77%)  [CORRECT]
#   > File: 097_3.png | True: real | Predicted: real (84.65%)  [CORRECT]
#   > File: 127_22.png | True: real | Predicted: real (91.27%)  [CORRECT]
#   > File: 070_5.png | True: real | Predicted: real (80.48%)  [CORRECT]
#   > File: 082_1.png | True: real | Predicted: real (98.28%)  [CORRECT]
#   > File: 120_10.png | True: real | Predicted: real (98.38%)  [CORRECT]
#   > File: 119_11.png | True: real | Predicted: real (94.72%)  [CORRECT]
#   > File: 114_0.png | True: real | Predicted: real (75.46%)  [CORRECT]
#   > File: 068_11.png | True: real | Predicted: real (94.85%)  [CORRECT]
#   > File: 106_1.png | True: real | Predicted: real (75.27%)  [CORRECT]
#   > File: 112_0.png | True: real | Predicted: real (86.46%)  [CORRECT]
#   > File: 073_2.png | True: real | Predicted: real (89.52%)  [CORRECT]
#   > File: 081_20.png | True: real | Predicted: real (95.87%)  [CORRECT]
#   > File: 073_14.png | True: real | Predicted: real (93.48%)  [CORRECT]
#   > File: 124_1.png | True: real | Predicted: real (73.64%)  [CORRECT]
#   > File: 079_6.png | True: real | Predicted: real (99.32%)  [CORRECT]
#   > File: 118_12.png | True: real | Predicted: real (93.02%)  [CORRECT]
#   > File: 126_10.png | True: real | Predicted: real (94.96%)  [CORRECT]
#   > File: 085_11.png | True: real | Predicted: real (98.76%)  [CORRECT]
#   > File: 086_6.png | True: real | Predicted: real (70.05%)  [CORRECT]
#   > File: 103_10.png | True: real | Predicted: real (93.63%)  [CORRECT]
#   > File: 107_13.png | True: real | Predicted: real (66.03%)  [CORRECT]
#   > File: 103_5.png | True: real | Predicted: real (87.87%)  [CORRECT]
#   > File: 103_14.png | True: real | Predicted: real (96.03%)  [CORRECT]
#   > File: 111_10.png | True: real | Predicted: real (91.77%)  [CORRECT]
#   > File: 121_1.png | True: real | Predicted: real (97.44%)  [CORRECT]
#   > File: 081_6.png | True: real | Predicted: real (84.18%)  [CORRECT]
#   > File: 101_28.png | True: real | Predicted: real (85.31%)  [CORRECT]
#   > File: 114_45.png | True: real | Predicted: real (58.85%)  [CORRECT]
#   > File: 070_1.png | True: real | Predicted: real (91.34%)  [CORRECT]
#   > File: 113_32.png | True: real | Predicted: real (96.56%)  [CORRECT]
#   > File: 117_4.png | True: real | Predicted: real (89.75%)  [CORRECT]
#   > File: 107_8.png | True: real | Predicted: real (83.74%)  [CORRECT]
#   > File: 082_7.png | True: real | Predicted: real (55.49%)  [CORRECT]
#   > File: 092_11.png | True: real | Predicted: real (50.10%)  [CORRECT]
#   > File: 075_10.png | True: real | Predicted: real (71.44%)  [CORRECT]
#   > File: 123_2.png | True: real | Predicted: real (74.15%)  [CORRECT]
#   > File: 116_2.png | True: real | Predicted: real (67.90%)  [CORRECT]
#   > File: 101_23.png | True: real | Predicted: real (93.84%)  [CORRECT]
#   > File: 088_7.png | True: real | Predicted: real (94.16%)  [CORRECT]
#   > File: 118_5.png | True: real | Predicted: real (94.19%)  [CORRECT]
#   > File: 088_20.png | True: real | Predicted: real (98.83%)  [CORRECT]
#   > File: 082_3.png | True: real | Predicted: real (52.44%)  [CORRECT]
#   > File: 084_13.png | True: real | Predicted: real (52.83%)  [CORRECT]
#   > File: 128_16.png | True: real | Predicted: real (55.59%)  [CORRECT]
#   > File: 114_30.png | True: real | Predicted: fake (60.95%)  [WRONG]
#   > File: 102_10.png | True: real | Predicted: real (80.74%)  [CORRECT]
#   > File: 073_24.png | True: real | Predicted: real (90.43%)  [CORRECT]
#   > File: 094_3.png | True: real | Predicted: fake (61.63%)  [WRONG]
#   > File: 110_10.png | True: real | Predicted: real (85.68%)  [CORRECT]
#   > File: 101_13.png | True: real | Predicted: real (86.44%)  [CORRECT]
#   > File: 128_14.png | True: real | Predicted: real (62.14%)  [CORRECT]
#   > File: 121_15.png | True: real | Predicted: real (95.91%)  [CORRECT]
#   > File: 081_29.png | True: real | Predicted: real (97.22%)  [CORRECT]
#   > File: 072_6.png | True: real | Predicted: real (75.97%)  [CORRECT]
#   > File: 086_8.png | True: real | Predicted: real (76.74%)  [CORRECT]
#   > File: 079_3.png | True: real | Predicted: real (98.63%)  [CORRECT]
#   > File: 086_0.png | True: real | Predicted: real (79.84%)  [CORRECT]
#   > File: 085_10.png | True: real | Predicted: real (95.35%)  [CORRECT]
#   > File: 075_19.png | True: real | Predicted: real (61.15%)  [CORRECT]
#   > File: 116_9.png | True: real | Predicted: real (77.26%)  [CORRECT]
#   > File: 114_25.png | True: real | Predicted: real (52.52%)  [CORRECT]
#   > File: 105_9.png | True: real | Predicted: real (90.18%)  [CORRECT]
#   > File: 110_8.png | True: real | Predicted: real (75.09%)  [CORRECT]
#   > File: 087_6.png | True: real | Predicted: real (90.56%)  [CORRECT]
#   > File: 077_9.png | True: real | Predicted: real (93.35%)  [CORRECT]
#   > File: 123_7.png | True: real | Predicted: real (63.26%)  [CORRECT]
#   > File: 071_1.png | True: real | Predicted: real (54.26%)  [CORRECT]
#   > File: 096_14.png | True: real | Predicted: real (87.85%)  [CORRECT]
#   > File: 120_6.png | True: real | Predicted: real (95.50%)  [CORRECT]
#   > File: 113_24.png | True: real | Predicted: real (86.90%)  [CORRECT]
#   > File: 083_10.png | True: real | Predicted: real (91.23%)  [CORRECT]
#   > File: 129_0.png | True: real | Predicted: real (88.28%)  [CORRECT]
#   > File: 108_0.png | True: real | Predicted: real (90.64%)  [CORRECT]
#   > File: 096_15.png | True: real | Predicted: real (85.67%)  [CORRECT]
#   > File: 112_6.png | True: real | Predicted: real (79.71%)  [CORRECT]
#   > File: 125_12.png | True: real | Predicted: real (84.24%)  [CORRECT]
#   > File: 089_24.png | True: real | Predicted: real (80.58%)  [CORRECT]
#   > File: 121_6.png | True: real | Predicted: real (97.95%)  [CORRECT]
#   > File: 128_8.png | True: real | Predicted: real (72.72%)  [CORRECT]
#   > File: 081_12.png | True: real | Predicted: real (95.47%)  [CORRECT]
#   > File: 089_25.png | True: real | Predicted: real (78.38%)  [CORRECT]
#   > File: 101_27.png | True: real | Predicted: real (93.05%)  [CORRECT]
#   > File: 119_10.png | True: real | Predicted: real (91.58%)  [CORRECT]
#   > File: 098_6.png | True: real | Predicted: real (97.90%)  [CORRECT]
#   > File: 070_6.png | True: real | Predicted: real (77.22%)  [CORRECT]
#   > File: 108_3.png | True: real | Predicted: real (70.25%)  [CORRECT]
#   > File: 119_2.png | True: real | Predicted: real (82.96%)  [CORRECT]
#   > File: 103_21.png | True: real | Predicted: real (93.12%)  [CORRECT]
#   > File: 120_3.png | True: real | Predicted: real (98.38%)  [CORRECT]
#   > File: 080_14.png | True: real | Predicted: real (79.55%)  [CORRECT]
#   > File: 114_20.png | True: real | Predicted: fake (50.08%)  [WRONG]
#   > File: 119_5.png | True: real | Predicted: real (90.07%)  [CORRECT]
#   > File: 110_18.png | True: real | Predicted: real (72.85%)  [CORRECT]
#   > File: 089_5.png | True: real | Predicted: real (73.36%)  [CORRECT]
#   > File: 081_22.png | True: real | Predicted: real (86.97%)  [CORRECT]
#   > File: 074_1.png | True: real | Predicted: real (98.64%)  [CORRECT]
#   > File: 102_0.png | True: real | Predicted: real (76.85%)  [CORRECT]
#   > File: 114_32.png | True: real | Predicted: real (50.95%)  [CORRECT]
#   > File: 126_4.png | True: real | Predicted: real (97.12%)  [CORRECT]
#   > File: 113_2.png | True: real | Predicted: real (94.94%)  [CORRECT]
#   > File: 079_11.png | True: real | Predicted: real (86.16%)  [CORRECT]
#   > File: 070_0.png | True: real | Predicted: real (93.88%)  [CORRECT]
#   > File: 082_6.png | True: real | Predicted: real (98.12%)  [CORRECT]
#   > File: 099_16.png | True: real | Predicted: real (97.11%)  [CORRECT]
#   > File: 121_9.png | True: real | Predicted: real (94.61%)  [CORRECT]
#   > File: 075_8.png | True: real | Predicted: real (65.16%)  [CORRECT]
#   > File: 069_22.png | True: real | Predicted: real (77.26%)  [CORRECT]
#   > File: 103_13.png | True: real | Predicted: real (95.03%)  [CORRECT]
#   > File: 092_6.png | True: real | Predicted: real (58.47%)  [CORRECT]
#   > File: 113_27.png | True: real | Predicted: real (90.24%)  [CORRECT]
#   > File: 124_10.png | True: real | Predicted: real (78.33%)  [CORRECT]
#   > File: 068_10.png | True: real | Predicted: real (89.35%)  [CORRECT]
#   > File: 118_1.png | True: real | Predicted: real (95.88%)  [CORRECT]
#   > File: 095_4.png | True: real | Predicted: real (94.42%)  [CORRECT]
#   > File: 082_12.png | True: real | Predicted: real (97.62%)  [CORRECT]
#   > File: 084_9.png | True: real | Predicted: real (64.52%)  [CORRECT]
#   > File: 071_9.png | True: real | Predicted: real (78.65%)  [CORRECT]
#   > File: 127_19.png | True: real | Predicted: real (66.48%)  [CORRECT]
#   > File: 073_10.png | True: real | Predicted: real (95.92%)  [CORRECT]
#   > File: 122_4.png | True: real | Predicted: real (78.41%)  [CORRECT]
#   > File: 095_25.png | True: real | Predicted: real (87.30%)  [CORRECT]
#   > File: 123_0.png | True: real | Predicted: real (78.55%)  [CORRECT]
#   > File: 094_18.png | True: real | Predicted: fake (89.09%)  [WRONG]
#   > File: 121_11.png | True: real | Predicted: real (97.23%)  [CORRECT]
#   > File: 088_16.png | True: real | Predicted: real (96.28%)  [CORRECT]
#   > File: 081_35.png | True: real | Predicted: real (91.12%)  [CORRECT]
#   > File: 101_0.png | True: real | Predicted: real (84.92%)  [CORRECT]
#   > File: 085_1.png | True: real | Predicted: real (98.30%)  [CORRECT]
#   > File: 103_15.png | True: real | Predicted: real (88.48%)  [CORRECT]
#   > File: 114_8.png | True: real | Predicted: fake (76.94%)  [WRONG]
#   > File: 114_13.png | True: real | Predicted: real (54.49%)  [CORRECT]
#   > File: 072_0.png | True: real | Predicted: real (75.85%)  [CORRECT]
#   > File: 117_13.png | True: real | Predicted: real (69.56%)  [CORRECT]
#   > File: 109_1.png | True: real | Predicted: real (77.30%)  [CORRECT]
#   > File: 114_39.png | True: real | Predicted: fake (54.44%)  [WRONG]
#   > File: 124_4.png | True: real | Predicted: real (72.01%)  [CORRECT]
#   > File: 112_10.png | True: real | Predicted: real (76.18%)  [CORRECT]
#   > File: 084_8.png | True: real | Predicted: real (87.86%)  [CORRECT]
#   > File: 110_5.png | True: real | Predicted: real (81.38%)  [CORRECT]
#   > File: 116_8.png | True: real | Predicted: real (75.79%)  [CORRECT]
#   > File: 081_17.png | True: real | Predicted: real (96.08%)  [CORRECT]
#   > File: 102_8.png | True: real | Predicted: real (69.39%)  [CORRECT]
#   > File: 084_2.png | True: real | Predicted: real (86.54%)  [CORRECT]
#   > File: 092_12.png | True: real | Predicted: real (61.39%)  [CORRECT]
#   > File: 069_4.png | True: real | Predicted: real (97.26%)  [CORRECT]
#   > File: 072_10.png | True: real | Predicted: real (65.30%)  [CORRECT]
#   > File: 125_1.png | True: real | Predicted: real (81.11%)  [CORRECT]
#   > File: 076_9.png | True: real | Predicted: real (96.88%)  [CORRECT]
#   > File: 086_13.png | True: real | Predicted: real (53.73%)  [CORRECT]
#   > File: 099_22.png | True: real | Predicted: real (95.79%)  [CORRECT]
#   > File: 093_12.png | True: real | Predicted: real (90.70%)  [CORRECT]
#   > File: 128_24.png | True: real | Predicted: real (56.71%)  [CORRECT]
#   > File: 075_0.png | True: real | Predicted: real (69.14%)  [CORRECT]
#   > File: 101_37.png | True: real | Predicted: real (89.93%)  [CORRECT]
#   > File: 082_8.png | True: real | Predicted: real (97.95%)  [CORRECT]
#   > File: 084_12.png | True: real | Predicted: fake (74.57%)  [WRONG]
#   > File: 078_14.png | True: real | Predicted: real (92.44%)  [CORRECT]
#   > File: 091_10.png | True: real | Predicted: real (95.34%)  [CORRECT]
#   > File: 081_25.png | True: real | Predicted: real (96.18%)  [CORRECT]
#   > File: 114_42.png | True: real | Predicted: real (68.07%)  [CORRECT]
#   > File: 072_2.png | True: real | Predicted: real (74.79%)  [CORRECT]
#   > File: 089_4.png | True: real | Predicted: real (60.70%)  [CORRECT]
#   > File: 114_37.png | True: real | Predicted: real (50.98%)  [CORRECT]
#   > File: 088_13.png | True: real | Predicted: real (95.27%)  [CORRECT]
#   > File: 069_23.png | True: real | Predicted: real (98.60%)  [CORRECT]
#   > File: 095_23.png | True: real | Predicted: real (95.99%)  [CORRECT]
#   > File: 068_5.png | True: real | Predicted: real (90.45%)  [CORRECT]
#   > File: 095_34.png | True: real | Predicted: real (77.38%)  [CORRECT]
#   > File: 101_14.png | True: real | Predicted: real (97.42%)  [CORRECT]
#   > File: 101_36.png | True: real | Predicted: real (91.85%)  [CORRECT]
#   > File: 101_6.png | True: real | Predicted: real (92.55%)  [CORRECT]
#   > File: 081_11.png | True: real | Predicted: real (95.42%)  [CORRECT]
#   > File: 105_5.png | True: real | Predicted: real (83.95%)  [CORRECT]
#   > File: 097_7.png | True: real | Predicted: real (73.02%)  [CORRECT]
#   > File: 100_10.png | True: real | Predicted: real (97.05%)  [CORRECT]
#   > File: 111_13.png | True: real | Predicted: real (51.42%)  [CORRECT]
#   > File: 113_19.png | True: real | Predicted: real (59.93%)  [CORRECT]
#   > File: 114_23.png | True: real | Predicted: real (53.78%)  [CORRECT]
#   > File: 110_7.png | True: real | Predicted: real (86.85%)  [CORRECT]
#   > File: 101_30.png | True: real | Predicted: real (64.24%)  [CORRECT]
#   > File: 077_13.png | True: real | Predicted: real (93.93%)  [CORRECT]
#   > File: 094_21.png | True: real | Predicted: fake (77.29%)  [WRONG]
#   > File: 096_5.png | True: real | Predicted: real (56.08%)  [CORRECT]
#   > File: 113_16.png | True: real | Predicted: real (91.55%)  [CORRECT]
#   > File: 087_4.png | True: real | Predicted: real (89.41%)  [CORRECT]
#   > File: 110_9.png | True: real | Predicted: real (66.17%)  [CORRECT]
#   > File: 095_10.png | True: real | Predicted: real (93.26%)  [CORRECT]
#   > File: 077_5.png | True: real | Predicted: real (88.55%)  [CORRECT]
#   > File: 113_9.png | True: real | Predicted: real (95.59%)  [CORRECT]
#   > File: 119_16.png | True: real | Predicted: real (88.93%)  [CORRECT]
#   > File: 106_4.png | True: real | Predicted: real (76.01%)  [CORRECT]
#   > File: 074_9.png | True: real | Predicted: real (92.59%)  [CORRECT]
#   > File: 074_11.png | True: real | Predicted: real (97.29%)  [CORRECT]
#   > File: 094_22.png | True: real | Predicted: fake (99.38%)  [WRONG]
#   > File: 077_22.png | True: real | Predicted: real (86.25%)  [CORRECT]
#   > File: 081_18.png | True: real | Predicted: real (95.87%)  [CORRECT]
#   > File: 107_6.png | True: real | Predicted: real (50.28%)  [CORRECT]
#   > File: 099_18.png | True: real | Predicted: real (98.37%)  [CORRECT]
#   > File: 103_3.png | True: real | Predicted: real (96.24%)  [CORRECT]
#   > File: 113_1.png | True: real | Predicted: real (96.55%)  [CORRECT]
#   > File: 111_2.png | True: real | Predicted: real (55.32%)  [CORRECT]
#   > File: 097_17.png | True: real | Predicted: real (67.94%)  [CORRECT]
#
# --- Evaluation Summary ---
# Total Images: 2400
# Correct Predictions: 2167
# OVERALL ACCURACY: 90.29%
# --------------------------
